# %% [markdown]
# # Cleaning the Trip Files

# %% [markdown]
# There are a huge amount of trip observations. I make it at about 30,000,000. The guy in the video said a couple million. I can't guarantee my count or his at the moment. The point is that they should perhaps be kept in separate files, but with consistent file and column names.

# %%
from cs1.tools import *

# %%
pwd()
# Out:
# '/home/fuzzy/DataAnalysisLab/Case_Study_1'

# %% [markdown]
# Since I'm more familiar with `pandas` than any other data manipulation tool, it's the one I'm starting with. My goal is to get all of the data into a `mysql` database and, preferably, to have the table for the trips partitioned by month (and year). The first hurdle to overcome, of course, is the inconsistency in the column names. I'm sure there's some history as to when and why the names were changed, but none of that is really relevant. The main point is just to make sure that they are consistent within the database. The most direct way to do that is to make them consistent in their CSV files.
#
# The `unique-trip_cols` function prints all of the column names found in all of the files.

# %%
columnize(unique_trip_cols())
# Out:
# start_station_name              start_time
# trip_id                         starttime
# "end_time"                      end_lng
# "bikeid"                        start_lat
# bikeid                          "gender"
# ended_at                        05 - Member Details Member Birthday Year
# from_station_id                 end_station_name
# usertype                        ride_id
# gender                          02 - Rental End Station Name
# 03 - Rental Start Station ID    "birthyear"
# start_lng                       end_time
# 03 - Rental Start Station Name  member_casual
# tripduration                    from_station_name
# to_station_id                   "to_station_id"
# started_at                      01 - Rental Details Local End Time
# "trip_id"                       02 - Rental End Station ID
# "to_station_name"               "start_time"
# 01 - Rental Details Rental ID   birthyear
# stoptime                        01 - Rental Details Local Start Time
# start_station_id                01 - Rental Details Bike ID
# "tripduration"                  User Type
# end_station_id                  "usertype"
# to_station_name                 end_lat
# "from_station_name"             01 - Rental Details Duration In Seconds Uncapped
# "starttime"                     "stoptime"
# rideable_type                   Member Gender
# "from_station_id"

# %%
consist_cols()
# Out:
# i=0
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202108-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=1
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2018_Q4.csv
# Columns: trip_id,start_time,end_time,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=2
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202007-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=3
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202008-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=4
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2017_Q2.csv
# Columns: "trip_id","start_time","end_time","bikeid","tripduration","from_station_id","from_station_name","to_station_id","to_station_name","usertype","gender","birthyear"
# New Columns: "ID","Start Time","End Time","Bike ID","Duration","From Station ID","From Station Name","To Station ID","To Station Name","User Type","Gender","Birth Year"
#
# i=5
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202005-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=6
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202010-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=7
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2016_Q4.csv
# Columns: "trip_id","starttime","stoptime","bikeid","tripduration","from_station_id","from_station_name","to_station_id","to_station_name","usertype","gender","birthyear"
# New Columns: "ID","Start Time","End Time","Bike ID","Duration","From Station ID","From Station Name","To Station ID","To Station Name","User Type","Gender","Birth Year"
#
# i=8
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202110-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=9
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202006-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=10
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2019_Q4.csv
# Columns: trip_id,start_time,end_time,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=11
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2016_Q1Q2/Divvy_Trips_2016_Q1.csv
# Columns: trip_id,starttime,stoptime,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=12
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2016_Q1Q2/Divvy_Trips_2016_05.csv
# Columns: trip_id,starttime,stoptime,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=13
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2016_Q1Q2/Divvy_Trips_2016_06.csv
# Columns: trip_id,starttime,stoptime,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=14
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2016_Q1Q2/Divvy_Trips_2016_04.csv
# Columns: trip_id,starttime,stoptime,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=15
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2015_08.csv
# Columns: trip_id,starttime,stoptime,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=16
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2019_Q3.csv
# Columns: trip_id,start_time,end_time,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=17
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202109-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=18
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2015_07.csv
# Columns: trip_id,starttime,stoptime,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=19
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202106-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=20
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202112-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=21
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202004-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=22
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2019_Q1.csv
# Columns: trip_id,start_time,end_time,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=23
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2018_Q3.csv
# Columns: trip_id,start_time,end_time,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=24
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2015-Q2.csv
# Columns: trip_id,starttime,stoptime,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=25
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202107-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=26
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202105-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=27
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2018_Q2.csv
# Columns: trip_id,start_time,end_time,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=28
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202104-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=29
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202012-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=30
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2014_Q1Q2.csv
# Columns: trip_id,starttime,stoptime,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=31
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2019_Q2.csv
# Columns: 01 - Rental Details Rental ID,01 - Rental Details Local Start Time,01 - Rental Details Local End Time,01 - Rental Details Bike ID,01 - Rental Details Duration In Seconds Uncapped,03 - Rental Start Station ID,03 - Rental Start Station Name,02 - Rental End Station ID,02 - Rental End Station Name,User Type,Member Gender,05 - Member Details Member Birthday Year
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=32
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2018_Q1.csv
# Columns: 01 - Rental Details Rental ID,01 - Rental Details Local Start Time,01 - Rental Details Local End Time,01 - Rental Details Bike ID,01 - Rental Details Duration In Seconds Uncapped,03 - Rental Start Station ID,03 - Rental Start Station Name,02 - Rental End Station ID,02 - Rental End Station Name,User Type,Member Gender,05 - Member Details Member Birthday Year
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=33
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Stations_Trips_2013/Divvy_Trips_2013.csv
# Columns: trip_id,starttime,stoptime,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthday
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=34
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202011-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=35
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2015_Q4.csv
# Columns: trip_id,starttime,stoptime,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=36
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202009-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=37
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202103-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=38
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202101-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=39
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2020_Q1.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=40
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202201-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=41
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2015-Q1.csv
# Columns: trip_id,starttime,stoptime,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=42
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2017_Q1.csv
# Columns: "trip_id","start_time","end_time","bikeid","tripduration","from_station_id","from_station_name","to_station_id","to_station_name","usertype","gender","birthyear"
# New Columns: "ID","Start Time","End Time","Bike ID","Duration","From Station ID","From Station Name","To Station ID","To Station Name","User Type","Gender","Birth Year"
#
# i=43
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2016_Q3.csv
# Columns: "trip_id","starttime","stoptime","bikeid","tripduration","from_station_id","from_station_name","to_station_id","to_station_name","usertype","gender","birthyear"
# New Columns: "ID","Start Time","End Time","Bike ID","Duration","From Station ID","From Station Name","To Station ID","To Station Name","User Type","Gender","Birth Year"
#
# i=44
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2017_Q4.csv
# Columns: trip_id,start_time,end_time,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=45
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Stations_Trips_2014_Q3Q4/Divvy_Trips_2014-Q3-0809.csv
# Columns: trip_id,starttime,stoptime,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=46
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Stations_Trips_2014_Q3Q4/Divvy_Trips_2014-Q4.csv
# Columns: trip_id,starttime,stoptime,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=47
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Stations_Trips_2014_Q3Q4/Divvy_Trips_2014-Q3-07.csv
# Columns: trip_id,starttime,stoptime,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=48
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2017_Q3.csv
# Columns: "trip_id","start_time","end_time","bikeid","tripduration","from_station_id","from_station_name","to_station_id","to_station_name","usertype","gender","birthyear"
# New Columns: "ID","Start Time","End Time","Bike ID","Duration","From Station ID","From Station Name","To Station ID","To Station Name","User Type","Gender","Birth Year"
#
# i=49
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2015_09.csv
# Columns: trip_id,starttime,stoptime,bikeid,tripduration,from_station_id,from_station_name,to_station_id,to_station_name,usertype,gender,birthyear
# New Columns: ID,Start Time,End Time,Bike ID,Duration,From Station ID,From Station Name,To Station ID,To Station Name,User Type,Gender,Birth Year
#
# i=50
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202102-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type
#
# i=51
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/202111-divvy-tripdata.csv
# Columns: ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# New Columns: ID,Bike Type,Start Time,End Time,From Station Name,From Station ID,To Station Name,To Station ID,Start Latitude,Start Longitude,End Latitude,End Longitude,User Type

# %%
FILES = list_trip_files(d=TEST_DIR)

# %%
len(FILES)
# Out:
# 52

# %%
COLS_2_KEEP = [
               'ID', 
               'Start Time',
               'End Time',
               'Bike ID',
               'Duration',
               'From Station ID',
               'To Station ID',
               'User Type',
               'Gender',
               'Birth Year',
               'To Station Name',
               'From Station Name',
               'End Latitude',
               'End Longitude',
               'Bike Type',
               'Start Latitude',
               'Start Longitude'
              ]

# %%
pp(COLS_LIST)
# Out:
# dict_keys(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration', 'From Station ID', 'To Station ID', 'User Type', 'Gender', 'Birth Year', 'To Station Name', 'From Station Name', 'End Latitude', 'End Longitude', 'Start Latitude', 'Start Longitude', 'Bike Type'])

# %%
def open_data_frame(p):
    cols_2_keep = COLS_2_KEEP
#     cols_2_keep.extend([f'"{s}"' for s in cols_2_keep])
#     columnize(cols_2_keep)
    print(f'Processing file: {p.name}')
    df = pd.read_csv(str(p))
    print(f'{df.columns=}')
    MAX_LEN = len(COLS_2_KEEP)
    cols_2_drop = list(set(df.columns).difference(cols_2_keep))
    print('Columns 2 Drop: ', cols_2_drop)
    df = df.drop(columns=cols_2_drop).reindex(columns=cols_2_keep)
    if len(df.columns) > MAX_LEN:
        df.drop(df.columns[MAX_LEN:], axis=1, inplace=True)
    print('New Columns: ', df.columns)
    return df

# %%
df = open_data_frame(FILES[1])
# Out:
# Processing file: Divvy_Trips_2018_Q4.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  []
# New Columns:  Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'To Station ID', 'User Type', 'Gender', 'Birth Year',
#        'To Station Name', 'From Station Name', 'End Latitude', 'End Longitude',
#        'Bike Type', 'Start Latitude', 'Start Longitude'],
#       dtype='object')

# %%
df
# Out:
#               ID           Start Time             End Time  Bike ID Duration  \
# 0       20983530  2018-10-01 00:01:17  2018-10-01 00:29:35     4551  1,698.0
# 1       20983531  2018-10-01 00:03:59  2018-10-01 00:10:55      847    416.0
# 2       20983532  2018-10-01 00:05:14  2018-10-01 00:14:08     6188    534.0
# 3       20983533  2018-10-01 00:05:48  2018-10-01 00:18:46     6372    778.0
# 4       20983534  2018-10-01 00:07:29  2018-10-01 00:25:51     1927  1,102.0
# ...          ...                  ...                  ...      ...      ...
# 642681  21742438  2018-12-31 23:45:17  2018-12-31 23:50:05     2931    288.0
# 642682  21742439  2018-12-31 23:48:48  2018-12-31 23:57:22     4386    514.0
# 642683  21742440  2018-12-31 23:50:09  2018-12-31 23:57:16     4927    427.0
# 642684  21742441  2018-12-31 23:55:04  2018-12-31 23:58:24     1350    200.0
# 642685  21742442  2018-12-31 23:59:18  2019-01-01 00:20:43     2006  1,285.0
#
#         From Station ID  To Station ID   User Type  Gender  Birth Year  \
# 0                    85            166  Subscriber    Male      1992.0
# 1                    13            144  Subscriber  Female      1982.0
# 2                    59            197  Subscriber    Male      1986.0
# 3                   328            419  Subscriber  Female      1960.0
# 4                    93            159  Subscriber  Female      1993.0
# ...                 ...            ...         ...     ...         ...
# 642681               49            164  Subscriber  Female      1983.0
# 642682              624             44  Subscriber  Female      1990.0
# 642683               41             52  Subscriber  Female      1995.0
# 642684              141            118  Subscriber    Male      1999.0
# 642685              260            166  Subscriber    Male      1990.0
#
#                      To Station Name               From Station Name  \
# 0       Ashland Ave & Wrightwood Ave           Michigan Ave & Oak St
# 1          Larrabee St & Webster Ave      Wilton Ave & Diversey Pkwy
# 2          Michigan Ave & Madison St       Wabash Ave & Roosevelt Rd
# 3            Lake Park Ave & 53rd St             Ellis Ave & 58th St
# 4          Claremont Ave & Hirsch St       Sheffield Ave & Willow St
# ...                              ...                             ...
# 642681         Franklin St & Lake St         Dearborn St & Monroe St
# 642682        State St & Randolph St  Dearborn St & Van Buren St (*)
# 642683        Michigan Ave & Lake St            Federal St & Polk St
# 642684       Sedgwick St & North Ave          Clark St & Lincoln Ave
# 642685  Ashland Ave & Wrightwood Ave      Kedzie Ave & Milwaukee Ave
#
#         End Latitude  End Longitude  Bike Type  Start Latitude  \
# 0                NaN            NaN        NaN             NaN
# 1                NaN            NaN        NaN             NaN
# 2                NaN            NaN        NaN             NaN
# 3                NaN            NaN        NaN             NaN
# 4                NaN            NaN        NaN             NaN
# ...              ...            ...        ...             ...
# 642681           NaN            NaN        NaN             NaN
# 642682           NaN            NaN        NaN             NaN
# 642683           NaN            NaN        NaN             NaN
# 642684           NaN            NaN        NaN             NaN
# 642685           NaN            NaN        NaN             NaN
#
#         Start Longitude
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 642681              NaN
# 642682              NaN
# 642683              NaN
# 642684              NaN
# 642685              NaN
#
# [642686 rows x 17 columns]

# %%
N = len(df)

# %%
len(df['ID'].unique()) == N
# Out:
# True

# %%
len(df['ID'].dropna()) == N
# Out:
# True

# %%
df.loc[N - 1, "Bike ID"] - df.loc[0, "Bike ID"] == N
# Out:
# False

# %%
len(df['Bike ID'].dropna()) == N
# Out:
# True

# %%
len(df['Bike ID'].unique())
# Out:
# 1

# %%
len(df['Duration'].dropna())
# Out:
# 0

# %%
ERRORS = dict()
for i in df.columns:
    ERRORS[i] = list()

# %%
ERR_INDEX = ["Nulls"]

# %%
for c in df.columns:
    ERRORS[c].append(len(df[df[c].isna()]))

# %%
ERRORS
# Out:
# {'ID': [0],
#  'Start Time': [0],
#  'End Time': [0],
#  'Bike ID': [0],
#  'Duration': [0],
#  'From Station ID': [0],
#  'To Station ID': [0],
#  'User Type': [0],
#  'Gender': [48382],
#  'Birth Year': [46166],
#  'To Station Name': [0],
#  'From Station Name': [0],
#  'End Latitude': [642686],
#  'End Longitude': [642686],
#  'Bike Type': [642686],
#  'Start Latitude': [642686],
#  'Start Longitude': [642686]}

# %%
errs_df = pd.DataFrame(ERRORS, index=ERR_INDEX)

# %%
errs_df
# Out:
#        ID  Start Time  End Time  Bike ID  Duration  From Station ID  \
# Nulls   0           0         0        0         0                0
#
#        To Station ID  User Type  Gender  Birth Year  To Station Name  \
# Nulls              0          0   48382       46166                0
#
#        From Station Name  End Latitude  End Longitude  Bike Type  \
# Nulls                  0        642686         642686     642686
#
#        Start Latitude  Start Longitude
# Nulls          642686           642686

# %%
stations = pd.read_csv(CLEAN_DIR / 'stations.csv')

# %%
help(pd.DataFrame.reindex)
# Out:
# Help on function reindex in module pandas.core.frame:
#
# reindex(self, labels=None, index=None, columns=None, axis=None, method=None, copy=True, level=None, fill_value=nan, limit=None, tolerance=None)
#     Conform Series/DataFrame to new index with optional filling logic.
#
#     Places NA/NaN in locations having no value in the previous index. A new object
#     is produced unless the new index is equivalent to the current one and
#     ``copy=False``.
#
#     Parameters
#     ----------
#
#     keywords for axes : array-like, optional
#         New labels / index to conform to, should be specified using
#         keywords. Preferably an Index object to avoid duplicating data.
#
#     method : {None, 'backfill'/'bfill', 'pad'/'ffill', 'nearest'}
#         Method to use for filling holes in reindexed DataFrame.
#         Please note: this is only applicable to DataFrames/Series with a
#         monotonically increasing/decreasing index.
#
#         * None (default): don't fill gaps
#         * pad / ffill: Propagate last valid observation forward to next
#           valid.
#         * backfill / bfill: Use next valid observation to fill gap.
#         * nearest: Use nearest valid observations to fill gap.
#
#     copy : bool, default True
#         Return a new object, even if the passed indexes are the same.
#     level : int or name
#         Broadcast across a level, matching Index values on the
#         passed MultiIndex level.
#     fill_value : scalar, default np.NaN
#         Value to use for missing values. Defaults to NaN, but can be any
#         "compatible" value.
#     limit : int, default None
#         Maximum number of consecutive elements to forward or backward fill.
#     tolerance : optional
#         Maximum distance between original and new labels for inexact
#         matches. The values of the index at the matching locations most
#         satisfy the equation ``abs(index[indexer] - target) <= tolerance``.
#
#         Tolerance may be a scalar value, which applies the same tolerance
#         to all values, or list-like, which applies variable tolerance per
#         element. List-like includes list, tuple, array, Series, and must be
#         the same size as the index and its dtype must exactly match the
#         index's type.
#
#     Returns
#     -------
#     Series/DataFrame with changed index.
#
#     See Also
#     --------
#     DataFrame.set_index : Set row labels.
#     DataFrame.reset_index : Remove row labels or move them to new columns.
#     DataFrame.reindex_like : Change to same indices as other DataFrame.
#
#     Examples
#     --------
#     ``DataFrame.reindex`` supports two calling conventions
#
#     * ``(index=index_labels, columns=column_labels, ...)``
#     * ``(labels, axis={'index', 'columns'}, ...)``
#
#     We *highly* recommend using keyword arguments to clarify your
#     intent.
#
#     Create a dataframe with some fictional data.
#
#     >>> index = ['Firefox', 'Chrome', 'Safari', 'IE10', 'Konqueror']
#     >>> df = pd.DataFrame({'http_status': [200, 200, 404, 404, 301],
#     ...                   'response_time': [0.04, 0.02, 0.07, 0.08, 1.0]},
#     ...                   index=index)
#     >>> df
#                http_status  response_time
#     Firefox            200           0.04
#     Chrome             200           0.02
#     Safari             404           0.07
#     IE10               404           0.08
#     Konqueror          301           1.00
#
#     Create a new index and reindex the dataframe. By default
#     values in the new index that do not have corresponding
#     records in the dataframe are assigned ``NaN``.
#
#     >>> new_index = ['Safari', 'Iceweasel', 'Comodo Dragon', 'IE10',
#     ...              'Chrome']
#     >>> df.reindex(new_index)
#                    http_status  response_time
#     Safari               404.0           0.07
#     Iceweasel              NaN            NaN
#     Comodo Dragon          NaN            NaN
#     IE10                 404.0           0.08
#     Chrome               200.0           0.02
#
#     We can fill in the missing values by passing a value to
#     the keyword ``fill_value``. Because the index is not monotonically
#     increasing or decreasing, we cannot use arguments to the keyword
#     ``method`` to fill the ``NaN`` values.
#
#     >>> df.reindex(new_index, fill_value=0)
#                    http_status  response_time
#     Safari                 404           0.07
#     Iceweasel                0           0.00
#     Comodo Dragon            0           0.00
#     IE10                   404           0.08
#     Chrome                 200           0.02
#
#     >>> df.reindex(new_index, fill_value='missing')
#                   http_status response_time
#     Safari                404          0.07
#     Iceweasel         missing       missing
#     Comodo Dragon     missing       missing
#     IE10                  404          0.08
#     Chrome                200          0.02
#
#     We can also reindex the columns.
#
#     >>> df.reindex(columns=['http_status', 'user_agent'])
#                http_status  user_agent
#     Firefox            200         NaN
#     Chrome             200         NaN
#     Safari             404         NaN
#     IE10               404         NaN
#     Konqueror          301         NaN
#
#     Or we can use "axis-style" keyword arguments
#
#     >>> df.reindex(['http_status', 'user_agent'], axis="columns")
#                http_status  user_agent
#     Firefox            200         NaN
#     Chrome             200         NaN
#     Safari             404         NaN
#     IE10               404         NaN
#     Konqueror          301         NaN
#
#     To further illustrate the filling functionality in
#     ``reindex``, we will create a dataframe with a
#     monotonically increasing index (for example, a sequence
#     of dates).
#
#     >>> date_index = pd.date_range('1/1/2010', periods=6, freq='D')
#     >>> df2 = pd.DataFrame({"prices": [100, 101, np.nan, 100, 89, 88]},
#     ...                    index=date_index)
#     >>> df2
#                 prices
#     2010-01-01   100.0
#     2010-01-02   101.0
#     2010-01-03     NaN
#     2010-01-04   100.0
#     2010-01-05    89.0
#     2010-01-06    88.0
#
#     Suppose we decide to expand the dataframe to cover a wider
#     date range.
#
#     >>> date_index2 = pd.date_range('12/29/2009', periods=10, freq='D')
#     >>> df2.reindex(date_index2)
#                 prices
#     2009-12-29     NaN
#     2009-12-30     NaN
#     2009-12-31     NaN
#     2010-01-01   100.0
#     2010-01-02   101.0
#     2010-01-03     NaN
#     2010-01-04   100.0
#     2010-01-05    89.0
#     2010-01-06    88.0
#     2010-01-07     NaN
#
#     The index entries that did not have a value in the original data frame
#     (for example, '2009-12-29') are by default filled with ``NaN``.
#     If desired, we can fill in the missing values using one of several
#     options.
#
#     For example, to back-propagate the last valid value to fill the ``NaN``
#     values, pass ``bfill`` as an argument to the ``method`` keyword.
#
#     >>> df2.reindex(date_index2, method='bfill')
#                 prices
#     2009-12-29   100.0
#     2009-12-30   100.0
#     2009-12-31   100.0
#     2010-01-01   100.0
#     2010-01-02   101.0
#     2010-01-03     NaN
#     2010-01-04   100.0
#     2010-01-05    89.0
#     2010-01-06    88.0
#     2010-01-07     NaN
#
#     Please note that the ``NaN`` value present in the original dataframe
#     (at index value 2010-01-03) will not be filled by any of the
#     value propagation schemes. This is because filling while reindexing
#     does not look at dataframe values, but only compares the original and
#     desired indexes. If you do want to fill in the ``NaN`` values present
#     in the original dataframe, use the ``fillna()`` method.
#
#     See the :ref:`user guide <basics.reindexing>` for more.

# %%
stations = stations.reindex(stations['ID']).drop(columns=['ID'])

# %%
stations
# Out:
#                             Name   Latitude  Longitude     City  DP Capacity  \
# ID
# 2                 Burnham Harbor  41.856268 -87.613348  Chicago         23.0
# 3         State St & Harrison St  41.874029 -87.627722  Chicago         19.0
# 4                 DuSable Harbor  41.885042 -87.612795  Chicago         39.0
# 5    Field Blvd & South Water St  41.886349 -87.617517  Chicago         19.0
# 6        Leavitt St & Archer Ave  41.828792 -87.680604  Chicago         19.0
# ..                           ...        ...        ...      ...          ...
# 622                          NaN        NaN        NaN      NaN          NaN
# 623                          NaN        NaN        NaN      NaN          NaN
# 624                          NaN        NaN        NaN      NaN          NaN
# 625                          NaN        NaN        NaN      NaN          NaN
# 626                          NaN        NaN        NaN      NaN          NaN
#
#      Landmark Online Date
# ID
# 2       545.0  2015-05-16
# 3        30.0  2013-06-28
# 4       548.0  2015-04-24
# 5       534.0  2015-04-18
# 6       695.0  2015-04-14
# ..        ...         ...
# 622       NaN         NaN
# 623       NaN         NaN
# 624       NaN         NaN
# 625       NaN         NaN
# 626       NaN         NaN
#
# [586 rows x 7 columns]

# %%
stations.columns[0]
# Out:
# 'ID'

# %%
from collections import namedtuple

# %%
def stations_data():
    stations = pd.read_csv(str(CLEAN_DIR / 'stations.csv'))
    stations.index = stations["ID"]
    return stations.drop(columns=["ID"])

# %%
stations = stations_data()

# %%
stations = None

# %%
missing_bikes = 0
START_LAT = "Start Latitude"
START_LNG = "Start Longitude"
FROM_ID = "From Station ID"
FROM_NAME = "From Station Name"

Coordinates = namedtuple('Coordinates', ["Latitude", "Longitude"])

def station_coords(i:int) -> Coordinates:
    global stations
    if stations is None:
        stations = stations_data()
    try:
        return Coordinates(stations["Latitude"][i], stations["Longitude"][i])
    except KeyError:
        print(f"Invalid station ID: {i}")
        return None

NA_START_LATS = df[START_LAT].isna()
NA_FROM_NAMES = df[FROM_NAME].isna()
NA_FROM_IDs   = df[FROM_ID].isna()

for i in df.index:
    if i in NA_START_LATS.index:
        if i in NA_FROM_IDs.index:
            from_station = df[FROM_ID][i]
        elif not i in NA_FROM_NAMES.index:
            from_station = get_station_id(df[FROM_NAME][i])
        else:
            print(f"Bad ride record, missing from station ID and name: {i}")
            break
        coords = station_coords(from_station)
        if not coords:
            print(f"Error getting station coordinates, line {i}.")
            df = df.drop(i)
            break
        df.loc[i, START_LAT] = coords.Latitude
        df.loc[i, START_LNG] = coords.Longitude
# Out:
# Invalid station ID: 627
# Error getting station coordinates, line 147.

# %%
df
# Out:
#               ID           Start Time             End Time  Bike ID Duration  \
# 0       20983530  2018-10-01 00:01:17  2018-10-01 00:29:35     4551  1,698.0
# 1       20983531  2018-10-01 00:03:59  2018-10-01 00:10:55      847    416.0
# 2       20983532  2018-10-01 00:05:14  2018-10-01 00:14:08     6188    534.0
# 3       20983533  2018-10-01 00:05:48  2018-10-01 00:18:46     6372    778.0
# 4       20983534  2018-10-01 00:07:29  2018-10-01 00:25:51     1927  1,102.0
# ...          ...                  ...                  ...      ...      ...
# 642681  21742438  2018-12-31 23:45:17  2018-12-31 23:50:05     2931    288.0
# 642682  21742439  2018-12-31 23:48:48  2018-12-31 23:57:22     4386    514.0
# 642683  21742440  2018-12-31 23:50:09  2018-12-31 23:57:16     4927    427.0
# 642684  21742441  2018-12-31 23:55:04  2018-12-31 23:58:24     1350    200.0
# 642685  21742442  2018-12-31 23:59:18  2019-01-01 00:20:43     2006  1,285.0
#
#         From Station ID  To Station ID   User Type  Gender  Birth Year  \
# 0                    85            166  Subscriber    Male      1992.0
# 1                    13            144  Subscriber  Female      1982.0
# 2                    59            197  Subscriber    Male      1986.0
# 3                   328            419  Subscriber  Female      1960.0
# 4                    93            159  Subscriber  Female      1993.0
# ...                 ...            ...         ...     ...         ...
# 642681               49            164  Subscriber  Female      1983.0
# 642682              624             44  Subscriber  Female      1990.0
# 642683               41             52  Subscriber  Female      1995.0
# 642684              141            118  Subscriber    Male      1999.0
# 642685              260            166  Subscriber    Male      1990.0
#
#                      To Station Name               From Station Name  \
# 0       Ashland Ave & Wrightwood Ave           Michigan Ave & Oak St
# 1          Larrabee St & Webster Ave      Wilton Ave & Diversey Pkwy
# 2          Michigan Ave & Madison St       Wabash Ave & Roosevelt Rd
# 3            Lake Park Ave & 53rd St             Ellis Ave & 58th St
# 4          Claremont Ave & Hirsch St       Sheffield Ave & Willow St
# ...                              ...                             ...
# 642681         Franklin St & Lake St         Dearborn St & Monroe St
# 642682        State St & Randolph St  Dearborn St & Van Buren St (*)
# 642683        Michigan Ave & Lake St            Federal St & Polk St
# 642684       Sedgwick St & North Ave          Clark St & Lincoln Ave
# 642685  Ashland Ave & Wrightwood Ave      Kedzie Ave & Milwaukee Ave
#
#         End Latitude  End Longitude  Bike Type  Start Latitude  \
# 0                NaN            NaN        NaN       41.900960
# 1                NaN            NaN        NaN       41.932449
# 2                NaN            NaN        NaN       41.867220
# 3                NaN            NaN        NaN       41.788746
# 4                NaN            NaN        NaN       41.913688
# ...              ...            ...        ...             ...
# 642681           NaN            NaN        NaN             NaN
# 642682           NaN            NaN        NaN             NaN
# 642683           NaN            NaN        NaN             NaN
# 642684           NaN            NaN        NaN             NaN
# 642685           NaN            NaN        NaN             NaN
#
#         Start Longitude
# 0            -87.623777
# 1            -87.652696
# 2            -87.625960
# 3            -87.601334
# 4            -87.652855
# ...                 ...
# 642681              NaN
# 642682              NaN
# 642683              NaN
# 642684              NaN
# 642685              NaN
#
# [642685 rows x 17 columns]

# %%
len(df[START_LAT].isna())
# Out:
# 642684

# %%
df = df.dropna(subset=['To Station ID'])

# %%
print(f'Number of thefts: {len(df[df["To Station ID"].isna()])}')
# Out:
# Number of thefts: 0

# %%
MIN_DATE = datetime(2013, 1, 1, 0, 0, 0)
MAX_DATE = datetime(2022, 1, 31, 0, 0, 0)

# %%
n = 0
for t in df['End Time']:
    d = parse(t)
    if d < MIN_DATE or d > MAX_DATE:
        n += 1

# %%
n
# Out:
# 0

# %%
df["Duration"] = parse()

# %%
df.iloc[2]["Start Time"]
# Out:
# '2020-05-02 14:11:03'

# %%
for i in range(len(df)):
    df["Duration"].iloc[i] = str(parse(df["End Time"].iloc[i]) - parse(df["Start Time"].iloc[i]))

# %%
df
# Out:
#                       ID           Start Time             End Time  \
# 0       02668AD35674B983  2020-05-27 10:03:52  2020-05-27 10:16:49
# 1       7A50CCAF1EDDB28F  2020-05-25 10:47:11  2020-05-25 11:05:40
# 2       2FFCDFDB91FE9A52  2020-05-02 14:11:03  2020-05-02 15:48:21
# 3       58991CF1DB75BA84  2020-05-02 16:25:36  2020-05-02 16:39:28
# 4       A79651EFECC268CD  2020-05-29 12:49:54  2020-05-29 13:27:11
# ...                  ...                  ...                  ...
# 200269  11C316914A7AF2F9  2020-05-30 12:48:07  2020-05-30 13:28:59
# 200270  DEA1AB8AB6A5E995  2020-05-30 20:21:32  2020-05-30 20:57:21
# 200271  D9EBC47F8C828B6E  2020-05-24 11:27:42  2020-05-24 11:35:20
# 200272  9744AA400432C99D  2020-05-06 17:18:46  2020-05-06 17:55:34
# 200273  FA58B8D38B2B3C83  2020-05-25 18:01:00  2020-05-25 18:40:25
#
#             Bike ID Duration  From Station ID  To Station ID User Type  \
# 0       docked_bike  0:12:57               36          199.0    member
# 1       docked_bike  0:18:29              340          326.0    casual
# 2       docked_bike  1:37:18              260          260.0    casual
# 3       docked_bike  0:13:52              251          157.0    casual
# 4       docked_bike  0:37:17              261          206.0    member
# ...             ...      ...              ...            ...       ...
# 200269  docked_bike  0:40:52              623          300.0    casual
# 200270  docked_bike  0:35:49              284          335.0    member
# 200271  docked_bike  0:07:38              144          343.0    casual
# 200272  docked_bike  0:36:48              463          464.0    member
# 200273  docked_bike  0:39:25               35           34.0    member
#
#         Gender  Birth Year                 To Station Name  \
# 0          NaN         NaN          Wabash Ave & Grand Ave
# 1          NaN         NaN           Clark St & Leland Ave
# 2          NaN         NaN      Kedzie Ave & Milwaukee Ave
# 3          NaN         NaN  Lake Shore Dr & Wellington Ave
# 4          NaN         NaN         Halsted St & Archer Ave
# ...        ...         ...                             ...
# 200269     NaN         NaN            Broadway & Barry Ave
# 200270     NaN         NaN           Calumet Ave & 35th St
# 200271     NaN         NaN     Racine Ave & Wrightwood Ave
# 200272     NaN         NaN          Damen Ave & Foster Ave
# 200273     NaN         NaN       Cannon Dr & Fullerton Ave
#
#                   From Station Name  End Latitude  End Longitude  \
# 0        Franklin St & Jackson Blvd       41.8915       -87.6268
# 1         Clark St & Wrightwood Ave       41.9671       -87.6674
# 2        Kedzie Ave & Milwaukee Ave       41.9296       -87.7079
# 3        Clarendon Ave & Leland Ave       41.9367       -87.6368
# 4           Hermitage Ave & Polk St       41.8472       -87.6468
# ...                             ...           ...            ...
# 200269        Michigan Ave & 8th St       41.9377       -87.6441
# 200270  Michigan Ave & Jackson Blvd       41.8314       -87.6180
# 200271    Larrabee St & Webster Ave       41.9289       -87.6590
# 200272        Clark St & Berwyn Ave       41.9756       -87.6795
# 200273      Streeter Dr & Grand Ave       41.9268       -87.6344
#
#         Ridable Type  Start Latitude  Start Longitude
# 0                NaN         41.8777         -87.6353
# 1                NaN         41.9295         -87.6431
# 2                NaN         41.9296         -87.7079
# 3                NaN         41.9680         -87.6500
# 4                NaN         41.8715         -87.6699
# ...              ...             ...              ...
# 200269           NaN         41.8728         -87.6240
# 200270           NaN         41.8779         -87.6241
# 200271           NaN         41.9218         -87.6441
# 200272           NaN         41.9780         -87.6680
# 200273           NaN         41.8923         -87.6120
#
# [199953 rows x 17 columns]

# %%
help(pd.Series.iloc)
# Out:
# Help on property:
#
#     Purely integer-location based indexing for selection by position.
#
#     ``.iloc[]`` is primarily integer position based (from ``0`` to
#     ``length-1`` of the axis), but may also be used with a boolean
#     array.
#
#     Allowed inputs are:
#
#     - An integer, e.g. ``5``.
#     - A list or array of integers, e.g. ``[4, 3, 0]``.
#     - A slice object with ints, e.g. ``1:7``.
#     - A boolean array.
#     - A ``callable`` function with one argument (the calling Series or
#       DataFrame) and that returns valid output for indexing (one of the above).
#       This is useful in method chains, when you don't have a reference to the
#       calling object, but would like to base your selection on some value.
#
#     ``.iloc`` will raise ``IndexError`` if a requested indexer is
#     out-of-bounds, except *slice* indexers which allow out-of-bounds
#     indexing (this conforms with python/numpy *slice* semantics).
#
#     See more at :ref:`Selection by Position <indexing.integer>`.
#
#     See Also
#     --------
#     DataFrame.iat : Fast integer location scalar accessor.
#     DataFrame.loc : Purely label-location based indexer for selection by label.
#     Series.iloc : Purely integer-location based indexing for
#                    selection by position.
#
#     Examples
#     --------
#
#     >>> mydict = [{'a': 1, 'b': 2, 'c': 3, 'd': 4},
#     ...           {'a': 100, 'b': 200, 'c': 300, 'd': 400},
#     ...           {'a': 1000, 'b': 2000, 'c': 3000, 'd': 4000 }]
#     >>> df = pd.DataFrame(mydict)
#     >>> df
#           a     b     c     d
#     0     1     2     3     4
#     1   100   200   300   400
#     2  1000  2000  3000  4000
#
#     **Indexing just the rows**
#
#     With a scalar integer.
#
#     >>> type(df.iloc[0])
#     <class 'pandas.core.series.Series'>
#     >>> df.iloc[0]
#     a    1
#     b    2
#     c    3
#     d    4
#     Name: 0, dtype: int64
#
#     With a list of integers.
#
#     >>> df.iloc[[0]]
#        a  b  c  d
#     0  1  2  3  4
#     >>> type(df.iloc[[0]])
#     <class 'pandas.core.frame.DataFrame'>
#
#     >>> df.iloc[[0, 1]]
#          a    b    c    d
#     0    1    2    3    4
#     1  100  200  300  400
#
#     With a `slice` object.
#
#     >>> df.iloc[:3]
#           a     b     c     d
#     0     1     2     3     4
#     1   100   200   300   400
#     2  1000  2000  3000  4000
#
#     With a boolean mask the same length as the index.
#
#     >>> df.iloc[[True, False, True]]
#           a     b     c     d
#     0     1     2     3     4
#     2  1000  2000  3000  4000
#
#     With a callable, useful in method chains. The `x` passed
#     to the ``lambda`` is the DataFrame being sliced. This selects
#     the rows whose index label even.
#
#     >>> df.iloc[lambda x: x.index % 2 == 0]
#           a     b     c     d
#     0     1     2     3     4
#     2  1000  2000  3000  4000
#
#     **Indexing both axes**
#
#     You can mix the indexer types for the index and columns. Use ``:`` to
#     select the entire axis.
#
#     With scalar integers.
#
#     >>> df.iloc[0, 1]
#     2
#
#     With lists of integers.
#
#     >>> df.iloc[[0, 2], [1, 3]]
#           b     d
#     0     2     4
#     2  2000  4000
#
#     With `slice` objects.
#
#     >>> df.iloc[1:3, 0:3]
#           a     b     c
#     1   100   200   300
#     2  1000  2000  3000
#
#     With a boolean array whose length matches the columns.
#
#     >>> df.iloc[:, [True, False, True, False]]
#           a     c
#     0     1     3
#     1   100   300
#     2  1000  3000
#
#     With a callable function that expects the Series or DataFrame.
#
#     >>> df.iloc[:, lambda df: [0, 2]]
#           a     c
#     0     1     3
#     1   100   300
#     2  1000  3000

# %%
# new_df.to_csv(str(CSV_DIR / trip_files[0].name), header=False, index=False)

# %%
(CSV_DIR / 'header.csv').write_text(','.join(cols_2_keep))

# %%
cd(DATA_DIR)
# Out:
# 'C:\\Users\\owner\\resume\\portfolio\\Case_Study_1\\data'

# %%
for p in [Path(f) for f in glob('*.csv') if f != '']:
    cols_2_keep = COLS_2_KEEP
    cols_2_keep.extend([f'"{s}"' for s in cols_2_keep])
    columnize(cols_2_keep)
    print(f'Processing file: {p.name}')
    df = pd.read_csv(str(p))
    print(f'{df.columns=}')
    cols_2_drop = list(set(df.columns).difference(cols_2_keep))
    print('Columns 2 Drop: ', cols_2_drop)
    df = df.drop(columns=cols_2_drop).reindex(columns=cols_2_keep)
    print('New Columns: ', df.columns)
    df.to_csv(str(CSV_DIR / 'header.csv'), mode='a', header=False, index=False)
    print()
# Out:
# Processing file: 202004-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202005-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202006-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202007-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202008-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202009-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202010-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202011-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202012-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202101-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202102-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202103-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202104-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202105-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202106-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202107-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202108-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202109-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202110-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202111-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202112-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: 202201-divvy-tripdata.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2013.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2014-Q3-07.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2014-Q3-0809.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2014-Q4.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2014_Q1Q2.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2015-Q1.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2015-Q2.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2015_07.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2015_08.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2015_09.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2015_Q4.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2016_04.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2016_05.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2016_06.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2016_Q1.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2016_Q3.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2016_Q4.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2017_Q1.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2017_Q2.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2017_Q3.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2017_Q4.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2018_Q1.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2018_Q2.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2018_Q3.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2018_Q4.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2019_Q1.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2019_Q2.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2019_Q3.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2019_Q4.csv
# df.columns=Index(['ID', 'Start Time', 'End Time', 'Bike ID', 'Duration',
#        'From Station ID', 'From Station Name', 'To Station ID',
#        'To Station Name', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
# Columns 2 Drop:  ['Duration', 'To Station Name', 'ID', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')
#
# Processing file: Divvy_Trips_2020_Q1.csv
# df.columns=Index(['ID', 'Bike ID', 'Start Time', 'End Time', 'From Station Name',
#        'From Station ID', 'To Station Name', 'To Station ID', 'Start Latitude',
#        'Start Longitude', 'End Latitude', 'End Longitude', 'User Type'],
#       dtype='object')
# Columns 2 Drop:  ['Start Latitude', 'End Latitude', 'Start Longitude', 'To Station Name', 'ID', 'End Longitude', 'From Station Name', 'Bike ID']
# New Columns:  Index(['Start Time', 'End Time', 'From Station ID', 'To Station ID',
#        'User Type', 'Gender', 'Birth Year'],
#       dtype='object')

# %%
GIANT_FILE = CSV_DIR / 'header.csv'

# %%
with GIANT_FILE.open() as f:
    print(f.readline())
# Out:
# Start Time,End Time,From Station ID,To Station ID,User Type,Gender,Birth Year,,,,,,

# %%
cd(CSV_DIR)
CSV_FILES = glob('*.csv')

# %%
CSV_FILES
# Out:
# ['202004-divvy-tripdata.csv',
#  '202005-divvy-tripdata.csv',
#  '202006-divvy-tripdata.csv',
#  '202007-divvy-tripdata.csv',
#  '202008-divvy-tripdata.csv',
#  '202009-divvy-tripdata.csv',
#  '202010-divvy-tripdata.csv',
#  '202011-divvy-tripdata.csv',
#  '202012-divvy-tripdata.csv',
#  '202101-divvy-tripdata.csv',
#  '202102-divvy-tripdata.csv',
#  '202103-divvy-tripdata.csv',
#  '202104-divvy-tripdata.csv',
#  '202105-divvy-tripdata.csv',
#  '202106-divvy-tripdata.csv',
#  '202107-divvy-tripdata.csv',
#  '202108-divvy-tripdata.csv',
#  '202109-divvy-tripdata.csv',
#  '202110-divvy-tripdata.csv',
#  '202111-divvy-tripdata.csv',
#  '202112-divvy-tripdata.csv',
#  '202201-divvy-tripdata.csv',
#  'Divvy_Trips_2013.csv',
#  'Divvy_Trips_2014-Q3-07.csv',
#  'Divvy_Trips_2014-Q3-0809.csv',
#  'Divvy_Trips_2014-Q4.csv',
#  'Divvy_Trips_2014_Q1Q2.csv',
#  'Divvy_Trips_2015-Q1.csv',
#  'Divvy_Trips_2015-Q2.csv',
#  'Divvy_Trips_2015_07.csv',
#  'Divvy_Trips_2015_08.csv',
#  'Divvy_Trips_2015_09.csv',
#  'Divvy_Trips_2015_Q4.csv',
#  'Divvy_Trips_2016_04.csv',
#  'Divvy_Trips_2016_05.csv',
#  'Divvy_Trips_2016_06.csv',
#  'Divvy_Trips_2016_Q1.csv',
#  'Divvy_Trips_2016_Q3.csv',
#  'Divvy_Trips_2016_Q4.csv',
#  'Divvy_Trips_2017_Q1.csv',
#  'Divvy_Trips_2017_Q2.csv',
#  'Divvy_Trips_2017_Q3.csv',
#  'Divvy_Trips_2017_Q4.csv',
#  'Divvy_Trips_2018_Q1.csv',
#  'Divvy_Trips_2018_Q2.csv',
#  'Divvy_Trips_2018_Q3.csv',
#  'Divvy_Trips_2018_Q4.csv',
#  'Divvy_Trips_2019_Q1.csv',
#  'Divvy_Trips_2019_Q2.csv',
#  'Divvy_Trips_2019_Q3.csv',
#  'Divvy_Trips_2019_Q4.csv',
#  'Divvy_Trips_2020_Q1.csv']

# %%
OUTPUT_FILE = TEST_DIR / 'trips.csv'
ATTRS_FILE = BASE_DIR / 'header.csv'
OUTPUT_FILE.write_text(ATTRS_FILE.read_text())
print(OUTPUT_FILE.read_text())
# Out:
# Start Time,End Time,From Station ID,To Station ID,User Type,Gender,Birth Year

# %%
with Path(CSV_FILES[0]).open() as f:
    s = f.readline()
    print(s)
# Out:
# 2020-04-26 17:45:14,2020-04-26 18:12:03,86,152.0,member,,

# %%
h = OUTPUT_FILE.read_text()

# %%
h
# Out:
# 'Start Time,End Time,From Station ID,To Station ID,User Type,Gender,Birth Year\n'

# %%
OUTPUT_FILE.write_text(h + '\n')
# Out:
# 78

# %%
with OUTPUT_FILE.open() as f:
    s = f.readline().rstrip('\n')
s
# Out:
# 'Start Time,End Time,From Station ID,To Station ID,User Type,Gender,Birth Year'

# %%
p = Path(CSV_FILES[0])

# %%
p
# Out:
# WindowsPath('202004-divvy-tripdata.csv')

# %%
with p.open() as f:
    s = f.readline().rstrip('\n')

# %%
s
# Out:
# '2020-04-26 17:45:14,2020-04-26 18:12:03,86,152.0,member,,'

# %%
s.rstrip('\n')
# Out:
# '2020-04-26 17:45:14,2020-04-26 18:12:03,86,152.0,member,,'

# %%
len(re.compile(',').findall(s))
# Out:
# 6

# %%
v = s.split(',')

# %%
v
# Out:
# ['2020-04-26 17:45:14', '2020-04-26 18:12:03', '86', '152.0', 'member', '', '']

# %%
start, end, origin, dest, user, gender, birth = v

# %%
birth
# Out:
# ''

# %%
start, end, origin, dest, user, gender, birth = s.split(',')
start = str(parse(start))
end = str(parse(end))
origin = int(origin.split('.')[0])
dest = int(dest.split('.')[0])
if birth:
    birth = str(parse(birth).year())

# %%
print(f'{start=}')
print(f'{end=}')
print(f'{origin=}')
print(f'{dest=}')
print(f'{birth=}')
# Out:
# start='2020-04-26 17:45:14'
# end='2020-04-26 18:12:03'
# origin=86
# dest=152
# birth=''

# %%
parse(start)
# Out:
# datetime.datetime(2020, 4, 26, 17, 45, 14)

# %%
str(start)
# Out:
# '2020-04-26 17:45:14'

# %%
cnx, cursor = db_connect()
# Out:
# Connected to database owner at 192.168.254.71

# %%
HEADER_FILE = BASE_DIR / 'header.csv'
SUBSCRIBER_TYPES = ['Dependent', 'Subscriber', 'member']
CUSTOMER_TYPES = ['Customer', 'casual']
UNIQUE_GENDERS = ['Female', 'Male']
HEADERS = (BASE_DIR / 'header.csv').read_text().rstrip('\n').split(',')

# %%
HEADERS
# Out:
# ['Start Time',
#  'End Time',
#  'From Station ID',
#  'To Station ID',
#  'User Type',
#  'Gender',
#  'Birth Year']

# %%
p = Path(CSV_FILES[38])
with p.open() as f:
    s = f.readline().rstrip('\n')
    start, end, origin, dest, user, gender, birth = s.split(',')
    start = str(parse(start))
    end = str(parse(end))
    origin = int(origin)
    if user:
        user = 'Subscriber' if user == 'member' else ('Customer' if user == 'casual' else user)
    dest = int(dest)
    if birth:
        birth = str(int(birth.split('.')[0]))
    else:
        birth = 0
    statement = f"""INSERT INTO trips(Start_Time, End_Time, From_Station_ID, To_Station_ID, User_Type, Gender, Birth_Year) VALUES('{start}', '{end}', '{origin}', '{dest}', '{user}', '{gender}', '{birth}');"""
    cursor.execute(statement)
    cnx.commit()

# %%
cnx.commit()

# %%
statement = f"""INSERT INTO Authors (First, Last) VALUES('{names[0]}', '{names[-1]}');"""

# %%
(BASE_DIR / 'header.csv').read_text().rstrip('\n')
# Out:
# 'Start Time,End Time,From Station ID,To Station ID,User Type,Gender,Birth Year'

# %%
HEADERS = (BASE_DIR / 'header.csv').read_text().rstrip('\n')
HEADERS
# Out:
# 'Start Time,End Time,From Station ID,To Station ID,User Type,Gender,Birth Year'

# %%
head_frame = pd.read_csv(HEADER_FILE)

# %%
head_frame
# Out:
# Empty DataFrame
# Columns: [Start Time, End Time, From Station ID, To Station ID, User Type, Gender, Birth Year]
# Index: []

# %%
file_frame = pd.read_csv(CSV_FILES[1], header=None)

# %%
file_frame
# Out:
#                           0                    1    2      3       4   5   6
# 0       2020-05-27 10:03:52  2020-05-27 10:16:49   36  199.0  member NaN NaN
# 1       2020-05-25 10:47:11  2020-05-25 11:05:40  340  326.0  casual NaN NaN
# 2       2020-05-02 14:11:03  2020-05-02 15:48:21  260  260.0  casual NaN NaN
# 3       2020-05-02 16:25:36  2020-05-02 16:39:28  251  157.0  casual NaN NaN
# 4       2020-05-29 12:49:54  2020-05-29 13:27:11  261  206.0  member NaN NaN
# ...                     ...                  ...  ...    ...     ...  ..  ..
# 200269  2020-05-30 12:48:07  2020-05-30 13:28:59  623  300.0  casual NaN NaN
# 200270  2020-05-30 20:21:32  2020-05-30 20:57:21  284  335.0  member NaN NaN
# 200271  2020-05-24 11:27:42  2020-05-24 11:35:20  144  343.0  casual NaN NaN
# 200272  2020-05-06 17:18:46  2020-05-06 17:55:34  463  464.0  member NaN NaN
# 200273  2020-05-25 18:01:00  2020-05-25 18:40:25   35   34.0  member NaN NaN
#
# [200274 rows x 7 columns]

# %%
file_frame.columns = head_frame.columns
df = pd.concat([head_frame, file_frame])
df
# Out:
#                  Start Time             End Time From Station ID  \
# 0       2020-05-27 10:03:52  2020-05-27 10:16:49              36
# 1       2020-05-25 10:47:11  2020-05-25 11:05:40             340
# 2       2020-05-02 14:11:03  2020-05-02 15:48:21             260
# 3       2020-05-02 16:25:36  2020-05-02 16:39:28             251
# 4       2020-05-29 12:49:54  2020-05-29 13:27:11             261
# ...                     ...                  ...             ...
# 200269  2020-05-30 12:48:07  2020-05-30 13:28:59             623
# 200270  2020-05-30 20:21:32  2020-05-30 20:57:21             284
# 200271  2020-05-24 11:27:42  2020-05-24 11:35:20             144
# 200272  2020-05-06 17:18:46  2020-05-06 17:55:34             463
# 200273  2020-05-25 18:01:00  2020-05-25 18:40:25              35
#
#         To Station ID User Type  Gender  Birth Year
# 0               199.0    member     NaN         NaN
# 1               326.0    casual     NaN         NaN
# 2               260.0    casual     NaN         NaN
# 3               157.0    casual     NaN         NaN
# 4               206.0    member     NaN         NaN
# ...               ...       ...     ...         ...
# 200269          300.0    casual     NaN         NaN
# 200270          335.0    member     NaN         NaN
# 200271          343.0    casual     NaN         NaN
# 200272          464.0    member     NaN         NaN
# 200273           34.0    member     NaN         NaN
#
# [200274 rows x 7 columns]

# %%
HEADER_FILE = BASE_DIR / 'header.csv'

def read_trip_csv_frame(f):
    h = pd.read_csv(HEADER_FILE)
    ff = pd.read_csv(f)
    ff.columns = h.columns
    return pd.concat([h, ff])

def unique_values(s):
    v = list()
    for f in CSV_FILES:
        df = read_trip_csv_frame(f)
        for u in df[s].dropna().unique():
            v.append(u)
    v = list(set(v))
    v.sort()
    if '' in v:
        v = v.remove('')
    return v

# %%
df = read_trip_csv_frame(CSV_FILES[4])

# %%
df
# Out:
#                  Start Time             End Time  From Station ID  \
# 0       2020-08-27 18:46:04  2020-08-27 19:54:51            168.0
# 1       2020-08-26 19:44:14  2020-08-26 21:53:07            195.0
# 2       2020-08-27 12:05:41  2020-08-27 12:53:45             81.0
# 3       2020-08-27 16:49:02  2020-08-27 16:59:49            658.0
# 4       2020-08-27 17:26:23  2020-08-27 18:07:50            658.0
# ...                     ...                  ...              ...
# 622355  2020-08-05 23:22:37  2020-08-05 23:31:33            627.0
# 622356  2020-08-08 23:42:41  2020-08-08 23:49:00            142.0
# 622357  2020-08-29 07:27:19  2020-08-29 07:54:26            122.0
# 622358  2020-08-04 19:43:13  2020-08-04 21:48:11            568.0
# 622359  2020-08-13 21:15:16  2020-08-13 21:29:01            144.0
#
#         To Station ID User Type  Gender  Birth Year
# 0               168.0    casual     NaN         NaN
# 1                44.0    casual     NaN         NaN
# 2                47.0    casual     NaN         NaN
# 3               658.0    casual     NaN         NaN
# 4               658.0    casual     NaN         NaN
# ...               ...       ...     ...         ...
# 622355           96.0    casual     NaN         NaN
# 622356          142.0    casual     NaN         NaN
# 622357           22.0    casual     NaN         NaN
# 622358          112.0    casual     NaN         NaN
# 622359          632.0    casual     NaN         NaN
#
# [622360 rows x 7 columns]

# %%
unique_values('User Type')
# Out:
# ['Customer', 'Dependent', 'Subscriber', 'casual', 'member']

# %%
unique_values('Gender')
# Out:
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'Female', 'Male']

# %%
unique_values('Birth Year')
# Out:
# [1759.0,
#  1790.0,
#  1888.0,
#  1889.0,
#  1890.0,
#  1895.0,
#  1898.0,
#  1899.0,
#  1900.0,
#  1901.0,
#  1904.0,
#  1905.0,
#  1906.0,
#  1909.0,
#  1910.0,
#  1911.0,
#  1912.0,
#  1915.0,
#  1916.0,
#  1918.0,
#  1920.0,
#  1921.0,
#  1922.0,
#  1923.0,
#  1925.0,
#  1927.0,
#  1928.0,
#  1929.0,
#  1930.0,
#  1931.0,
#  1932.0,
#  1933.0,
#  1934.0,
#  1935.0,
#  1936.0,
#  1937.0,
#  1938.0,
#  1939.0,
#  1940.0,
#  1941.0,
#  1942.0,
#  1943.0,
#  1944.0,
#  1945.0,
#  1946.0,
#  1947.0,
#  1948.0,
#  1949.0,
#  1950.0,
#  1951.0,
#  1952.0,
#  1953.0,
#  1954.0,
#  1955.0,
#  1956.0,
#  1957.0,
#  1958.0,
#  1959.0,
#  1960.0,
#  1961.0,
#  1962.0,
#  1963.0,
#  1964.0,
#  1965.0,
#  1966.0,
#  1967.0,
#  1968.0,
#  1969.0,
#  1970.0,
#  1971.0,
#  1972.0,
#  1973.0,
#  1974.0,
#  1975.0,
#  1976.0,
#  1977.0,
#  1978.0,
#  1979.0,
#  1980.0,
#  1981.0,
#  1982.0,
#  1983.0,
#  1984.0,
#  1985.0,
#  1986.0,
#  1987.0,
#  1988.0,
#  1989.0,
#  1990.0,
#  1991.0,
#  1992.0,
#  1993.0,
#  1994.0,
#  1995.0,
#  1996.0,
#  1997.0,
#  1998.0,
#  1999.0,
#  2000.0,
#  2001.0,
#  2002.0,
#  2003.0,
#  2004.0,
#  2005.0,
#  2014.0,
#  2016.0,
#  2017.0]

# %%
STAGED_DIR = BASE_DIR / 'staged'

OUTPUT_FILE = STAGED_DIR / 'trips.csv'

# %%
trip_files
# Out:
# [WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2015_07.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202012-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202005-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202103-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2018_Q3.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202111-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202006-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2017_Q4.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202104-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_06.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_Q1Q2/Divvy_Trips_2016_Q1.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202008-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2019_Q4.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202009-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202007-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_05.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2020_Q1.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202109-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Stations_Trips_2014_Q3Q4/Divvy_Trips_2014-Q4.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202010-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2019_Q3.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2019_Q2.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2018_Q1.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_Q1Q2/Divvy_Trips_2016_04.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Stations_Trips_2013/Divvy_Trips_2013.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202110-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202112-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2015_Q4.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_Q1.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2017_Q1.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202101-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Stations_Trips_2014_Q3Q4/Divvy_Trips_2014-Q3-07.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2014-Q3-0809.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2015-Q2.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_Q1Q2/Divvy_Trips_2016_06.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2015_08.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202107-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2017_Q2.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_Q4.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2017_Q3.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2019_Q1.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2014-Q4.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_Q1Q2/Divvy_Trips_2016_05.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202201-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202004-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2018_Q2.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202102-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202011-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2015-Q1.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202105-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2015_09.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202106-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_Q3.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2014-Q3-07.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202108-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Stations_Trips_2014_Q3Q4/Divvy_Trips_2014-Q3-0809.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2018_Q4.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2014_Q1Q2.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2013.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_04.csv')]

# %%
cd(CSV_DIR)
CSV_FILES = [Path(s) for s in glob('**')]
OUTPUT_FILE.write_text(HEADER_FILE.read_text() + '\n')
n = 0
with OUTPUT_FILE.open(mode='a+') as out:
    for p in CSV_FILES:
        print(p)
        with p.open() as f:
            while True:
                s = f.readline()
                if not s:
                    break
                print(s.rstrip('\n'), file=out)
                n += 1
print(f'{n=}')
# Out:
# 202004-divvy-tripdata.csv
# 202005-divvy-tripdata.csv
# 202006-divvy-tripdata.csv
# 202007-divvy-tripdata.csv
# 202008-divvy-tripdata.csv
# 202009-divvy-tripdata.csv
# 202010-divvy-tripdata.csv
# 202011-divvy-tripdata.csv
# 202012-divvy-tripdata.csv
# 202101-divvy-tripdata.csv
# 202102-divvy-tripdata.csv
# 202103-divvy-tripdata.csv
# 202104-divvy-tripdata.csv
# 202105-divvy-tripdata.csv
# 202106-divvy-tripdata.csv
# 202107-divvy-tripdata.csv
# 202108-divvy-tripdata.csv
# 202109-divvy-tripdata.csv
# 202110-divvy-tripdata.csv
# 202111-divvy-tripdata.csv
# 202112-divvy-tripdata.csv
# 202201-divvy-tripdata.csv
# Divvy_Trips_2013.csv
# Divvy_Trips_2014-Q3-07.csv
# Divvy_Trips_2014-Q3-0809.csv
# Divvy_Trips_2014-Q4.csv
# Divvy_Trips_2014_Q1Q2.csv
# Divvy_Trips_2015-Q1.csv
# Divvy_Trips_2015-Q2.csv
# Divvy_Trips_2015_07.csv
# Divvy_Trips_2015_08.csv
# Divvy_Trips_2015_09.csv
# Divvy_Trips_2015_Q4.csv
# Divvy_Trips_2016_04.csv
# Divvy_Trips_2016_05.csv
# Divvy_Trips_2016_06.csv
# Divvy_Trips_2016_Q1.csv
# Divvy_Trips_2016_Q3.csv
# Divvy_Trips_2016_Q4.csv
# Divvy_Trips_2017_Q1.csv
# Divvy_Trips_2017_Q2.csv
# Divvy_Trips_2017_Q3.csv
# Divvy_Trips_2017_Q4.csv
# Divvy_Trips_2018_Q1.csv
# Divvy_Trips_2018_Q2.csv
# Divvy_Trips_2018_Q3.csv
# Divvy_Trips_2018_Q4.csv
# Divvy_Trips_2019_Q1.csv
# Divvy_Trips_2019_Q2.csv
# Divvy_Trips_2019_Q3.csv
# Divvy_Trips_2019_Q4.csv
# Divvy_Trips_2020_Q1.csv
# n=30483860

# %%
Path(OUTPUT_FILE).read_text()
# Out:
# 'Start Time,End Time,From Station ID,To Station ID,User Type,Gender,Birth Year'

# %%
CSV_FILES = [Path(s) for s in glob('**')]

# %%
# Out:
# 'Start Time,End Time,From Station ID,To Station ID,User Type,Gender,Birth Year'
# '2020-04-26 17:45:14,2020-04-26 18:12:03,86,152.0,member,,'
# '2020-04-17 17:08:54,2020-04-17 17:17:03,503,499.0,member,,'
# '2020-04-01 17:54:13,2020-04-01 18:08:36,142,255.0,member,,'
# '2020-04-07 12:50:19,2020-04-07 13:02:31,216,657.0,member,,'
# '2020-04-18 10:22:59,2020-04-18 11:15:54,125,323.0,casual,,'
# '2020-04-30 17:55:47,2020-04-30 18:01:11,173,35.0,member,,'
# '2020-04-02 14:47:19,2020-04-02 14:52:32,35,635.0,member,,'
# '2020-04-07 12:22:20,2020-04-07 13:38:09,434,382.0,casual,,'
# '2020-04-15 10:30:11,2020-04-15 10:35:55,627,359.0,casual,,'
# '2020-04-04 15:02:28,2020-04-04 15:19:47,377,508.0,member,,'
# '2020-04-04 15:22:43,2020-04-04 15:46:55,508,374.0,member,,'
# '2020-04-25 15:43:52,2020-04-25 15:48:45,374,128.0,member,,'
# '2020-04-24 18:09:43,2020-04-24 18:18:01,374,210.0,member,,'
# '2020-04-11 17:15:19,2020-04-11 17:19:53,374,128.0,member,,'
# '2020-04-20 17:18:50,2020-04-20 17:42:51,321,623.0,member,,'
# '2020-04-18 15:49:26,2020-04-18 16:24:57,321,20.0,member,,'
# '2020-04-19 13:39:57,2020-04-19 14:01:39,321,141.0,member,,'
# '2020-04-18 02:59:09,2020-04-18 03:07:22,9,9.0,casual,,'
# '2020-04-04 10:52:08,2020-04-04 11:08:03,141,190.0,casual,,'

# %%
(TEST_DIR / 'trips.csv').write_text(HEADER_FILE.read_text() + '\n' + CSV_FILES[12].read_text())
# Out:
# 22465086

# %%
def check_trip_files():
    pp(trip_files)

# %%
check_trip_files()
# Out:
# [WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2015_07.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202012-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202005-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202103-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2018_Q3.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202111-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202006-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2017_Q4.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202104-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_06.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_Q1Q2/Divvy_Trips_2016_Q1.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202008-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2019_Q4.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202009-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202007-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_05.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2020_Q1.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202109-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Stations_Trips_2014_Q3Q4/Divvy_Trips_2014-Q4.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202010-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2019_Q3.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2019_Q2.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2018_Q1.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_Q1Q2/Divvy_Trips_2016_04.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Stations_Trips_2013/Divvy_Trips_2013.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202110-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202112-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2015_Q4.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_Q1.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2017_Q1.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202101-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Stations_Trips_2014_Q3Q4/Divvy_Trips_2014-Q3-07.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2014-Q3-0809.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2015-Q2.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_Q1Q2/Divvy_Trips_2016_06.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2015_08.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202107-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2017_Q2.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_Q4.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2017_Q3.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2019_Q1.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2014-Q4.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_Q1Q2/Divvy_Trips_2016_05.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202201-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202004-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2018_Q2.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202102-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202011-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2015-Q1.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202105-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2015_09.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202106-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_Q3.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2014-Q3-07.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/202108-divvy-tripdata.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Stations_Trips_2014_Q3Q4/Divvy_Trips_2014-Q3-0809.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2018_Q4.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2014_Q1Q2.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2013.csv'),
#  WindowsPath('C:/Users/owner/resume/portfolio/Case_Study_1/data/Divvy_Trips_2016_04.csv')]

# %%
df = pd.read_csv(CSV_FILES[12])

# %%
df
# Out:
#         2021-04-12 18:25:36  2021-04-12 18:56:55  TA1307000061         13235  \
# 0       2021-04-27 17:27:11  2021-04-27 18:31:29  KA1503000069  KA1503000069
# 1       2021-04-03 12:42:45  2021-04-07 11:40:24         20121         20121
# 2       2021-04-17 09:17:42  2021-04-17 09:42:48  TA1305000034         13235
# 3       2021-04-03 12:42:25  2021-04-03 14:13:42         20121         20121
# 4       2021-04-25 18:43:18  2021-04-25 18:43:59         15542         15542
# ...                     ...                  ...           ...           ...
# 337224  2021-04-09 17:09:03  2021-04-09 17:16:16         15529         13017
# 337225  2021-04-04 13:27:08  2021-04-04 14:41:11         15529         13022
# 337226  2021-04-30 18:15:40  2021-04-30 19:12:44         15529         13022
# 337227  2021-04-18 11:40:37  2021-04-18 11:46:03         15529         13017
# 337228  2021-04-23 19:22:16  2021-04-23 19:41:07         13292         13243
#
#         member  Unnamed: 5  Unnamed: 6
# 0       casual         NaN         NaN
# 1       casual         NaN         NaN
# 2       member         NaN         NaN
# 3       casual         NaN         NaN
# 4       casual         NaN         NaN
# ...        ...         ...         ...
# 337224  member         NaN         NaN
# 337225  casual         NaN         NaN
# 337226  member         NaN         NaN
# 337227  member         NaN         NaN
# 337228  member         NaN         NaN
#
# [337229 rows x 7 columns]

# %%
CSV_FILES[12].name
# Out:
# '202104-divvy-tripdata.csv'

# %%
cd(DATA_DIR)
# Out:
# 'C:\\Users\\owner\\resume\\portfolio\\Case_Study_1\\data'

# %%
df = pd.read_csv(CSV_FILES[12].name)

# %%
df
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       6C992BD37A98A63F   classic_bike  2021-04-12 18:25:36
# 1       1E0145613A209000    docked_bike  2021-04-27 17:27:11
# 2       E498E15508A80BAD    docked_bike  2021-04-03 12:42:45
# 3       1887262AD101C604   classic_bike  2021-04-17 09:17:42
# 4       C123548CAB2A32A5    docked_bike  2021-04-03 12:42:25
# ...                  ...            ...                  ...
# 337225  461A6B0728E063DB   classic_bike  2021-04-09 17:09:03
# 337226  CF1D3A35E3654F6F    docked_bike  2021-04-04 13:27:08
# 337227  4308ADB9171ACE49   classic_bike  2021-04-30 18:15:40
# 337228  04DFB53077A17DA2  electric_bike  2021-04-18 11:40:37
# 337229  DB6F78ABBECA378C   classic_bike  2021-04-23 19:22:16
#
#                    ended_at                   start_station_name  \
# 0       2021-04-12 18:56:55                State St & Pearson St
# 1       2021-04-27 18:31:29             Dorchester Ave & 49th St
# 2       2021-04-07 11:40:24                Loomis Blvd & 84th St
# 3       2021-04-17 09:42:48              Honore St & Division St
# 4       2021-04-03 14:13:42                Loomis Blvd & 84th St
# ...                     ...                                  ...
# 337225  2021-04-09 17:16:16  Mies van der Rohe Way & Chestnut St
# 337226  2021-04-04 14:41:11  Mies van der Rohe Way & Chestnut St
# 337227  2021-04-30 19:12:44  Mies van der Rohe Way & Chestnut St
# 337228  2021-04-18 11:46:03  Mies van der Rohe Way & Chestnut St
# 337229  2021-04-23 19:41:07               Kedzie Ave & Palmer Ct
#
#        start_station_id              end_station_name end_station_id  \
# 0          TA1307000061  Southport Ave & Waveland Ave          13235
# 1          KA1503000069      Dorchester Ave & 49th St   KA1503000069
# 2                 20121         Loomis Blvd & 84th St          20121
# 3          TA1305000034  Southport Ave & Waveland Ave          13235
# 4                 20121         Loomis Blvd & 84th St          20121
# ...                 ...                           ...            ...
# 337225            15529     Franklin St & Chicago Ave          13017
# 337226            15529       Streeter Dr & Grand Ave          13022
# 337227            15529       Streeter Dr & Grand Ave          13022
# 337228            15529     Franklin St & Chicago Ave          13017
# 337229            13292  Milwaukee Ave & Wabansia Ave          13243
#
#         start_lat  start_lng    end_lat    end_lng member_casual
# 0       41.897448 -87.628722  41.948150 -87.663940        member
# 1       41.805772 -87.592464  41.805772 -87.592464        casual
# 2       41.741487 -87.658410  41.741487 -87.658410        casual
# 3       41.903119 -87.673935  41.948150 -87.663940        member
# 4       41.741487 -87.658410  41.741487 -87.658410        casual
# ...           ...        ...        ...        ...           ...
# 337225  41.898587 -87.621915  41.896747 -87.635668        member
# 337226  41.898587 -87.621915  41.892278 -87.612043        casual
# 337227  41.898587 -87.621915  41.892278 -87.612043        member
# 337228  41.898263 -87.622416  41.894942 -87.630438        member
# 337229  41.921525 -87.707322  41.912616 -87.681391        member
#
# [337230 rows x 13 columns]
