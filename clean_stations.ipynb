# %% [markdown]
# # Cleaning the Station Files

# %% [markdown]
# ### Local Imports

# %%
from cs1.tools import *

# %%
cd(BASE_DIR)
# Out:
# '/home/fuzzy/DataAnalysisLab/Case_Study_1'

# %%
sys.version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_115228/967655980.py in <module>
# ----> 1 sys.version
#
# NameError: name 'sys' is not defined

# %% [markdown]
# ### Station Files

# %%
STATION_FILES
# Out:
# [PosixPath('/home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Stations_2015.csv'),
#  PosixPath('/home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2016_Q1Q2/Divvy_Stations_2016_Q1Q2.csv'),
#  PosixPath('/home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Stations_2017_Q1Q2.csv'),
#  PosixPath('/home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Stations_2017_Q3Q4.csv'),
#  PosixPath('/home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Stations_Trips_2013/Divvy_Stations_2013.csv'),
#  PosixPath('/home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Stations_2016_Q4.csv'),
#  PosixPath('/home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Stations_2016_Q3.csv'),
#  PosixPath('/home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Stations_Trips_2014_Q3Q4/Divvy_Stations_2014-Q3Q4.csv')]

# %%
station_cols = list()
for p in STATION_FILES:
    with p.open() as f:
        new_list = [s.strip().strip('"') for s in next(f).strip().split(',')]
        while len(new_list) < MAX_COLS:
            new_list.append('')
        station_cols.append(new_list)

set([str(L) for L in station_cols])
# Out:
# {"['id', 'name', 'city', 'latitude', 'longitude', 'dpcapacity', 'online_date', '', '', '', '', '', '', '']",
#  "['id', 'name', 'latitude', 'longitude', 'dpcapacity', 'dateCreated', '', '', '', '', '', '', '', '']",
#  "['id', 'name', 'latitude', 'longitude', 'dpcapacity', 'landmark', '', '', '', '', '', '', '', '']",
#  "['id', 'name', 'latitude', 'longitude', 'dpcapacity', 'landmark', 'online date', '', '', '', '', '', '', '']",
#  "['id', 'name', 'latitude', 'longitude', 'dpcapacity', 'online_date', '', '', '', '', '', '', '', '']"}

# %%
new_station_cols = ['ID', 'Name', 'City', 'Latitude', 'Longitude', 'DP Capacity', 'Landmark', 'Online Date']

# %%
cols = dict()
for i in range(len(new_station_cols)):
    cols[new_station_cols[i]] = list()

cols['ID'] = 'id'
cols['Name'] = 'name'
cols['City'] = 'city'
cols['Latitude'] = 'latitude'
cols['Longitude'] = 'longitude'
cols['DP Capacity'] = 'dpcapacity'
cols['Landmark'] = 'landmark'
cols['Online Date'] = ['online date', 'online_date', 'dateCreated']

# %%
cols
# Out:
# {'ID': 'id',
#  'Name': 'name',
#  'City': 'city',
#  'Latitude': 'latitude',
#  'Longitude': 'longitude',
#  'DP Capacity': 'dpcapacity',
#  'Landmark': 'landmark',
#  'Online Date': ['online date', 'online_date', 'dateCreated']}

# %%
def combine_station_files():
    df_sum = pd.DataFrame()
    for f in STATION_FILES:
    #     if not f.name == 'Divvy_Stations_2017_Q3Q4.csv':
        print(f'Processing {f}')
        df = pd.read_csv(f)
        new_cols = list()
        UNNAMED = False
        for s in df.columns:
            if regex_in_list(r'Unnamed: \d', df.columns):
                print("Dropping column...")
                df = df.drop("Unnamed: 7", axis=1)
        for s in df.columns:
            try:
                k = reverse_lookup(cols, s)
                assert(k)
            except AssertionError as e:
                print(f'Bad lookup value: {s}')
                print(f'File: {f.name}')
            new_cols.append(k)
    #     try:    
    #         df.columns = new_cols
    #         df.reindex(columns=new_station_cols)
    # #         print(df.head())
    #     except ValueError as e:
    #         print(f'Value Error: {f}')
    #         print_exc()
        if not len(df_sum):
            df_sum = df
        else:
            df_sum = pd.concat([df_sum, df])

    #     print(df_sum.describe())
        print(f'{len(df_sum)=}\n')
    
    return df_sum.sort_values("ID")

# %%
combine_station_files()
# Out:
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Stations_2015.csv
# len(df_sum)=474
#
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Trips_2016_Q1Q2/Divvy_Stations_2016_Q1Q2.csv
# len(df_sum)=1009
#
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Stations_2017_Q1Q2.csv
# len(df_sum)=1591
#
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Stations_2017_Q3Q4.csv
# Bad lookup value: Unnamed: 7
# File: Divvy_Stations_2017_Q3Q4.csv
# Dropping column...
# len(df_sum)=2176
#
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Stations_Trips_2013/Divvy_Stations_2013.csv
# len(df_sum)=2476
#
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Stations_2016_Q4.csv
# len(df_sum)=3057
#
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Stations_2016_Q3.csv
# len(df_sum)=3638
#
# Processing /home/fuzzy/DataAnalysisLab/Case_Study_1/data/Divvy_Stations_Trips_2014_Q3Q4/Divvy_Stations_2014-Q3Q4.csv
# len(df_sum)=3938
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_115228/336553603.py in <module>
# ----> 1 combine_station_files()
#
# /tmp/ipykernel_115228/4014781052.py in combine_station_files()
#      32         print(f'{len(df_sum)=}\n')
#      33
# ---> 34     return df_sum.sort_values("ID")
#
# ~/anaconda3/envs/RStudio/lib/python3.10/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/envs/RStudio/lib/python3.10/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6305
#    6306             by = by[0]
# -> 6307             k = self._get_label_or_level_values(by, axis=axis)
#    6308
#    6309             # need to rewrap column in Series to apply key function
#
# ~/anaconda3/envs/RStudio/lib/python3.10/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1846             values = self.axes[axis].get_level_values(key)._values
#    1847         else:
# -> 1848             raise KeyError(key)
#    1849
#    1850         # Check for duplicates
#
# KeyError: 'ID'

# %%
df
# Out:
#       ID                            Name   Latitude  Longitude  DP Capacity  \
# 0      2        Michigan Ave & Balbo Ave  41.872293 -87.624091           35
# 47     2             Buckingham Fountain  41.872667 -87.623971           35
# 0      2             Buckingham Fountain  41.876393 -87.620328           27
# 47     2             Buckingham Fountain  41.872667 -87.623971           35
# 0      2        Michigan Ave & Balbo Ave  41.872293 -87.624091           35
# ..   ...                             ...        ...        ...          ...
# 582  624  Dearborn St & Van Buren St (*)  41.876268 -87.629155           16
# 583  625       Chicago Ave & Dempster St  42.041691 -87.680687           15
# 583  625       Chicago Ave & Dempster St  42.041691 -87.680687           15
# 584  626        Delano Ct & Roosevelt Rd  41.867491 -87.632190           19
# 584  626        Delano Ct & Roosevelt Rd  41.867491 -87.632190           19
#
#      Landmark       Online Date      City
# 0       541.0               NaN       NaN
# 47        NaN          5/8/2015       NaN
# 0         NaN   6/10/2013 10:43   Chicago
# 47        NaN          5/8/2015       NaN
# 0       541.0               NaN       NaN
# ..        ...               ...       ...
# 582       NaN   7/26/2017 21:25   Chicago
# 583       NaN   8/11/2017 16:53  Evanston
# 583       NaN   8/11/2017 16:53  Evanston
# 584       NaN  12/21/2017 22:06   Chicago
# 584       NaN  12/21/2017 22:06   Chicago
#
# [7876 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Latitude', 'Longitude', 'DP Capacity', 'Landmark',
#        'Online Date', 'City'],
#       dtype='object')

# %%
len(df['ID'].unique())
# Out:
# 586

# %%
backup_df = df.copy()

# %%
# df = backup_df

# %%
df["Name"] = df["Name"].replace(' (\*)', '')

# %%
type(df["Online Date"].dtype)
# Out:
# numpy.dtype[object_]

# %%
new_df = pd.DataFrame()
print("Running")
IDs = df['ID'].unique()
print(f'{len(IDs)=}')
print()
for i in IDs:
    print(f'{i=}')
    df2 = df[df['ID']==i].sort_values("Online Date", ascending=False)
#     df2.reindex(index=range(len(df2)))
#     print(df2)
    print()
    
    L = list()
    for s in df2["Online Date"].dropna():
        try:
            L.append(parse(s).date())
        except TypeError as e:
            print(f"""
TYPE ERROR:
Online Date String: {s}
                  """)
    L = set(L)
    print(f'Online Dates: {L}')
    print(f'Most recent date: {max(L)}')
    most_recent_date = max(L)
    
    names = list()
    for s, n in zip(df2["Online Date"], df2["Name"]):
        try:
#             print(type(s))
#             print(f'{s=}\n{n=}')
            if type(s) is str and parse(s).date() == most_recent_date:
                names.append(n)
        except:
            pass
    print(f'{names=}')
    unique_names = list(set(names))
    unique_names.sort()
    print(f'{unique_names=}')
    d = dict()
    C = ["Name","Popularity"]
    for c in C:
        d[c] = list()
    for n in unique_names:
        d["Name"].append(n)
        d["Popularity"].append(len(df2[df2["Name"] == n]))
    print(d)
    popular_names = pd.DataFrame(d).sort_values("Popularity", ascending=False)
    print(popular_names)
    name = popular_names["Name"][0]
    print(f'{name=}')
    
    C = df2['City'].dropna()
    city = None
    print(f'{C=}')
    if C.any():
        for c in C:
            city = c
            break
#     print(f'{type(city)=}')

    lats = df2["Latitude"]
    diff = max(lats) - min(lats) if len(df2) > 1 else 0
    if diff > 0.01:
        print("WARNING: Difference in latitude > 0.01")
        print(f'{len(df2)=}')
        print(f'{max(lats)=}')
        print(f'{min(lats)=}')
        print(f'{diff=}')
        print(i)
        print()
    lons = df2["Longitude"]
    diff = max(lons) - min(lons) if len(df2) > 1 else 0
    if diff > 0.01:
        print("WARNING: Difference in longitude > 0.01")
        print(f'{len(df2)=}')
        print(f'{max(lons)=}')
        print(f'{min(lons)=}')
        print(f'{diff=}')
        print(i)
        print()
    if (lats < 40).any() or (lats > 43).any() or (lons < -89).any() or (lons > -85).any():
        print("WARNING: Unreasonable latitude and/or longitude!")
        print(i)
        print()
        
    latitude = mean(lats)
    longitude = mean(lons)
    print(f'{city=}')
    print(f'{latitude=}')
    print(f'{longitude=}')
    
    C = df2['DP Capacity'].dropna()
    dpcapacity = None
#     print(f'{C=}')
    if C.any():
        for c in C:
            dpcapacity = c
            break
            
    C = df2['Landmark'].dropna()
    landmark = None
#     print(f'{C=}')
    if C.any():
        for c in C:
            landmark = c
            break
            
    d = {"ID": [i],
         "Name": [name],
         "Latitude": [latitude],
         "Longitude": [longitude],
         "City": [city],
         "DP Capacity": [dpcapacity],
         "Landmark": [landmark],
         "Online Date": [most_recent_date]}
            
    row = pd.DataFrame(d, index=[i]) # dtype=[("ID", int), ("Name", str), ("Latitude", float), ("Longitude", float), ("City", str),
                                       #     ("DP Capacity", int), ("Landmark", float), ("Online Date", str)])
            
    new_df = pd.concat([new_df, row])
    
    print()

#     if i > 5:
#         break
        
print(new_df)
# Out:
# Running
# len(IDs)=586
#
# i=2
#
# Online Dates: {datetime.date(2015, 5, 8), datetime.date(2013, 6, 10)}
# Most recent date: 2015-05-08
# names=['Buckingham Fountain', 'Buckingham Fountain', 'Michigan Ave & Balbo Ave', 'Michigan Ave & Balbo Ave', 'Michigan Ave & Balbo Ave', 'Michigan Ave & Balbo Ave']
# unique_names=['Buckingham Fountain', 'Michigan Ave & Balbo Ave']
# {'Name': ['Buckingham Fountain', 'Michigan Ave & Balbo Ave'], 'Popularity': [6, 6]}
#                        Name  Popularity
# 0       Buckingham Fountain           6
# 1  Michigan Ave & Balbo Ave           6
# name='Buckingham Fountain'
# C=52    Chicago
# 52    Chicago
# 0     Chicago
# 0     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.87461483333333
# longitude=-87.62263899999999
#
# i=3
#
# Online Dates: {datetime.date(2015, 4, 24), datetime.date(2013, 6, 10)}
# Most recent date: 2015-04-24
# names=['Shedd Aquarium', 'Shedd Aquarium', 'Shedd Aquarium', 'Shedd Aquarium', 'Shedd Aquarium', 'Shedd Aquarium']
# unique_names=['Shedd Aquarium']
# {'Name': ['Shedd Aquarium'], 'Popularity': [12]}
#              Name  Popularity
# 0  Shedd Aquarium          12
# name='Shedd Aquarium'
# C=440    Chicago
# 440    Chicago
# 1      Chicago
# 1      Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.867225966136665
# longitude=-87.61535532503335
#
# i=4
#
# Online Dates: {datetime.date(2015, 5, 16), datetime.date(2013, 6, 10)}
# Most recent date: 2015-05-16
# names=['Burnham Harbor', 'Burnham Harbor', 'Burnham Harbor', 'Burnham Harbor', 'Burnham Harbor', 'Burnham Harbor']
# unique_names=['Burnham Harbor']
# {'Name': ['Burnham Harbor'], 'Popularity': [12]}
#              Name  Popularity
# 0  Burnham Harbor          12
# name='Burnham Harbor'
# C=54    Chicago
# 54    Chicago
# 2     Chicago
# 2     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.856268
# longitude=-87.61334799999999
#
# i=5
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 18), datetime.date(2013, 6, 10)}
# Most recent date: 2013-06-28
# names=['State St & Harrison St', 'State St & Harrison St']
# unique_names=['State St & Harrison St']
# {'Name': ['State St & Harrison St'], 'Popularity': [16]}
#                      Name  Popularity
# 0  State St & Harrison St          16
# name='State St & Harrison St'
# C=480    Chicago
# 480    Chicago
# 3      Chicago
# 3      Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.874029265000004
# longitude=-87.6277218725
#
# i=6
#
# Online Dates: {datetime.date(2015, 4, 24), datetime.date(2013, 6, 10)}
# Most recent date: 2015-04-24
# names=['DuSable Harbor', 'Dusable Harbor', 'DuSable Harbor', 'Dusable Harbor', 'Dusable Harbor', 'Dusable Harbor']
# unique_names=['DuSable Harbor', 'Dusable Harbor']
# {'Name': ['DuSable Harbor', 'Dusable Harbor'], 'Popularity': [2, 10]}
#              Name  Popularity
# 1  Dusable Harbor          10
# 0  DuSable Harbor           2
# name='DuSable Harbor'
# C=182    Chicago
# 182    Chicago
# 4      Chicago
# 4      Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.88504182705333
# longitude=-87.61279452656667
#
# i=7
#
# Online Dates: {datetime.date(2015, 4, 18), datetime.date(2013, 6, 19)}
# Most recent date: 2015-04-18
# names=['Field Blvd & South Water St', 'Field Blvd & South Water St', 'Field Blvd & South Water St', 'Field Blvd & South Water St', 'Field Blvd & South Water St', 'Field Blvd & South Water St']
# unique_names=['Field Blvd & South Water St']
# {'Name': ['Field Blvd & South Water St'], 'Popularity': [12]}
#                           Name  Popularity
# 0  Field Blvd & South Water St          12
# name='Field Blvd & South Water St'
# C=201    Chicago
# 201    Chicago
# 5      Chicago
# 5      Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.88634905044833
# longitude=-87.61751662451667
#
# i=9
#
# Online Dates: {datetime.date(2013, 6, 21), datetime.date(2015, 4, 14)}
# Most recent date: 2015-04-14
# names=['Leavitt St & Archer Ave', 'Leavitt St & Archer Ave', 'Leavitt St & Archer Ave', 'Leavitt St & Archer Ave', 'Leavitt St & Archer Ave', 'Leavitt St & Archer Ave']
# unique_names=['Leavitt St & Archer Ave']
# {'Name': ['Leavitt St & Archer Ave'], 'Popularity': [12]}
#                       Name  Popularity
# 0  Leavitt St & Archer Ave          12
# name='Leavitt St & Archer Ave'
# C=6      Chicago
# 6      Chicago
# 306    Chicago
# 306    Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.82879201665666
# longitude=-87.68060438323334
#
# i=11
#
# Online Dates: {datetime.date(2015, 4, 22), datetime.date(2013, 6, 21)}
# Most recent date: 2015-04-22
# names=['Jeffery Blvd & 71st St', 'Jeffery Blvd & 71st St', 'Jeffery Blvd & 71st St', 'Jeffery Blvd & 71st St', 'Jeffery Blvd & 71st St', 'Jeffery Blvd & 71st St']
# unique_names=['Jeffery Blvd & 71st St']
# {'Name': ['Jeffery Blvd & 71st St'], 'Popularity': [12]}
#                      Name  Popularity
# 0  Jeffery Blvd & 71st St          12
# name='Jeffery Blvd & 71st St'
# C=7      Chicago
# 7      Chicago
# 252    Chicago
# 252    Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.76663819949167
# longitude=-87.57645009235
#
# i=12
#
# Online Dates: {datetime.date(2015, 4, 22), datetime.date(2013, 6, 21)}
# Most recent date: 2015-04-22
# names=['South Shore Dr & 71st St', 'South Shore Dr & 71st St', 'South Shore Dr & 71st St', 'South Shore Dr & 71st St', 'South Shore Dr & 71st St', 'South Shore Dr & 71st St']
# unique_names=['South Shore Dr & 71st St']
# {'Name': ['South Shore Dr & 71st St'], 'Popularity': [12]}
#                        Name  Popularity
# 0  South Shore Dr & 71st St          12
# name='South Shore Dr & 71st St'
# C=460    Chicago
# 460    Chicago
# 8      Chicago
# 8      Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.76640938278333
# longitude=-87.56568764198333
#
# i=13
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 22), datetime.date(2013, 6, 20)}
# Most recent date: 2013-06-28
# names=['Wilton Ave & Diversey Pkwy', 'Wilton Ave & Diversey Pkwy']
# unique_names=['Wilton Ave & Diversey Pkwy']
# {'Name': ['Wilton Ave & Diversey Pkwy'], 'Popularity': [16]}
#                          Name  Popularity
# 0  Wilton Ave & Diversey Pkwy          16
# name='Wilton Ave & Diversey Pkwy'
# C=546    Chicago
# 546    Chicago
# 9      Chicago
# 9      Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.93244878
# longitude=-87.65269593250001
#
# i=14
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 22), datetime.date(2013, 6, 20)}
# Most recent date: 2013-06-28
# names=['Morgan St & 18th St', 'Morgan St & 18th St']
# unique_names=['Morgan St & 18th St']
# {'Name': ['Morgan St & 18th St'], 'Popularity': [16]}
#                   Name  Popularity
# 0  Morgan St & 18th St          16
# name='Morgan St & 18th St'
# C=364    Chicago
# 364    Chicago
# 10     Chicago
# 10     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.858086
# longitude=-87.651073
#
# i=15
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 22), datetime.date(2013, 6, 20)}
# Most recent date: 2013-06-28
# names=['Racine Ave & 18th St', 'Racine Ave & 18th St']
# unique_names=['Racine Ave & 18th St']
# {'Name': ['Racine Ave & 18th St'], 'Popularity': [14]}
#                    Name  Popularity
# 0  Racine Ave & 18th St          14
# name='Racine Ave & 18th St'
# C=404    Chicago
# 404    Chicago
# 11     Chicago
# 11     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.85795370125
# longitude=-87.65649095625
#
# i=16
#
# Online Dates: {datetime.date(2013, 8, 12), datetime.date(2013, 6, 22)}
# Most recent date: 2013-08-12
# names=['Paulina Ave & North Ave', 'Paulina Ave & North Ave', 'Wood St & North Ave', 'Paulina Ave & North Ave', 'Paulina Ave & North Ave', 'Paulina Ave & North Ave', 'Wood St & North Ave', 'Paulina Ave & North Ave']
# unique_names=['Paulina Ave & North Ave', 'Wood St & North Ave']
# {'Name': ['Paulina Ave & North Ave', 'Wood St & North Ave'], 'Popularity': [10, 6]}
#                       Name  Popularity
# 0  Paulina Ave & North Ave          10
# 1      Wood St & North Ave           6
# name='Paulina Ave & North Ave'
# C=384    Chicago
# 384    Chicago
# 12     Chicago
# 12     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.910334
# longitude=-87.67098849999999
#
# i=17
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 22), datetime.date(2013, 6, 20)}
# Most recent date: 2013-06-28
# names=['Wood St & Division St', 'Wood St & Division St']
# unique_names=['Wood St & Division St']
# {'Name': ['Wood St & Division St'], 'Popularity': [14]}
#                     Name  Popularity
# 0  Wood St & Division St          14
# name='Wood St & Division St'
# C=551    Chicago
# 551    Chicago
# 13     Chicago
# 13     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.903294875
# longitude=-87.672880625
#
# i=18
#
# Online Dates: {datetime.date(2015, 4, 18), datetime.date(2013, 6, 22)}
# Most recent date: 2015-04-18
# names=['Wacker Dr & Washington St', 'Wacker Dr & Washington St', 'Wacker Dr & Washington St', 'Wacker Dr & Washington St', 'Wacker Dr & Washington St', 'Wacker Dr & Washington St']
# unique_names=['Wacker Dr & Washington St']
# {'Name': ['Wacker Dr & Washington St'], 'Popularity': [12]}
#                         Name  Popularity
# 0  Wacker Dr & Washington St          12
# name='Wacker Dr & Washington St'
# C=514    Chicago
# 514    Chicago
# 14     Chicago
# 14     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.883248393755
# longitude=-87.63731452615
#
# i=19
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 21), datetime.date(2013, 6, 22)}
# Most recent date: 2013-06-28
# names=['Loomis St & Taylor St', 'Loomis St & Taylor St']
# unique_names=['Loomis St & Taylor St']
# {'Name': ['Loomis St & Taylor St'], 'Popularity': [8]}
#                     Name  Popularity
# 0  Loomis St & Taylor St           8
# name='Loomis St & Taylor St'
# C=323    Chicago
# 323    Chicago
# 15     Chicago
# 15     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.869417
# longitude=-87.660996
#
# i=20
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 21), datetime.date(2013, 6, 22)}
# Most recent date: 2013-06-28
# names=['Sheffield Ave & Kingsbury St', 'Sheffield Ave & Kingsbury St']
# unique_names=['Sheffield Ave & Kingsbury St']
# {'Name': ['Sheffield Ave & Kingsbury St'], 'Popularity': [16]}
#                            Name  Popularity
# 0  Sheffield Ave & Kingsbury St          16
# name='Sheffield Ave & Kingsbury St'
# C=442    Chicago
# 442    Chicago
# 16     Chicago
# 16     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.91017322374999
# longitude=-87.65325271125
#
# i=21
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 21), datetime.date(2013, 6, 22)}
# Most recent date: 2013-06-28
# names=['Aberdeen St & Jackson Blvd', 'Aberdeen St & Jackson Blvd']
# unique_names=['Aberdeen St & Jackson Blvd']
# {'Name': ['Aberdeen St & Jackson Blvd'], 'Popularity': [16]}
#                          Name  Popularity
# 0  Aberdeen St & Jackson Blvd          16
# name='Aberdeen St & Jackson Blvd'
# C=3     Chicago
# 3     Chicago
# 17    Chicago
# 17    Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.87772611375
# longitude=-87.65478737625
#
# i=22
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 21), datetime.date(2013, 6, 22)}
# Most recent date: 2013-06-28
# names=['May St & Taylor St', 'May St & Taylor St']
# unique_names=['May St & Taylor St']
# {'Name': ['May St & Taylor St'], 'Popularity': [16]}
#                  Name  Popularity
# 0  May St & Taylor St          16
# name='May St & Taylor St'
# C=333    Chicago
# 333    Chicago
# 18     Chicago
# 18     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.8694820875
# longitude=-87.65548635
#
# i=23
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 21), datetime.date(2013, 6, 22)}
# Most recent date: 2013-06-28
# names=['Orleans St & Elm St', 'Orleans St & Elm St']
# unique_names=['Orleans St & Elm St']
# {'Name': ['Orleans St & Elm St'], 'Popularity': [8]}
#                   Name  Popularity
# 0  Orleans St & Elm St           8
# name='Orleans St & Elm St'
# C=381    Chicago
# 381    Chicago
# 19     Chicago
# 19     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.902924
# longitude=-87.637715
#
# i=24
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 21), datetime.date(2013, 6, 22)}
# Most recent date: 2013-06-28
# names=['Fairbanks Ct & Grand Ave', 'Fairbanks Ct & Grand Ave']
# unique_names=['Fairbanks Ct & Grand Ave']
# {'Name': ['Fairbanks Ct & Grand Ave'], 'Popularity': [16]}
#                        Name  Popularity
# 0  Fairbanks Ct & Grand Ave          16
# name='Fairbanks Ct & Grand Ave'
# C=198    Chicago
# 198    Chicago
# 20     Chicago
# 20     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.89186
# longitude=-87.62062
#
# i=25
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 22)}
# Most recent date: 2013-06-28
# names=['Michigan Ave & Pearson St', 'Michigan Ave & Pearson St']
# unique_names=['Michigan Ave & Pearson St']
# {'Name': ['Michigan Ave & Pearson St'], 'Popularity': [16]}
#                         Name  Popularity
# 0  Michigan Ave & Pearson St          16
# name='Michigan Ave & Pearson St'
# C=345    Chicago
# 345    Chicago
# 21     Chicago
# 21     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.89766
# longitude=-87.62351
#
# i=26
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 22)}
# Most recent date: 2013-06-28
# names=['McClurg Ct & Illinois St', 'McClurg Ct & Illinois St']
# unique_names=['McClurg Ct & Illinois St']
# {'Name': ['McClurg Ct & Illinois St'], 'Popularity': [16]}
#                        Name  Popularity
# 0  McClurg Ct & Illinois St          16
# name='McClurg Ct & Illinois St'
# C=335    Chicago
# 335    Chicago
# 22     Chicago
# 22     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.89093737500001
# longitude=-87.617329
#
# i=27
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 22)}
# Most recent date: 2013-06-28
# names=['Larrabee St & North Ave', 'Larrabee St & North Ave']
# unique_names=['Larrabee St & North Ave']
# {'Name': ['Larrabee St & North Ave'], 'Popularity': [16]}
#                       Name  Popularity
# 0  Larrabee St & North Ave          16
# name='Larrabee St & North Ave'
# C=297    Chicago
# 297    Chicago
# 23     Chicago
# 23     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.91021
# longitude=-87.6435
#
# i=28
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 22)}
# Most recent date: 2013-06-28
# names=['Larrabee St & Menomonee St', 'Larrabee St & Menomonee St']
# unique_names=['Larrabee St & Menomonee St']
# {'Name': ['Larrabee St & Menomonee St'], 'Popularity': [16]}
#                          Name  Popularity
# 0  Larrabee St & Menomonee St          16
# name='Larrabee St & Menomonee St'
# C=296    Chicago
# 296    Chicago
# 24     Chicago
# 24     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.91468
# longitude=-87.64331999999999
#
# i=29
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 22)}
# Most recent date: 2013-06-28
# names=['Noble St & Milwaukee Ave', 'Noble St & Milwaukee Ave']
# unique_names=['Noble St & Milwaukee Ave']
# {'Name': ['Noble St & Milwaukee Ave'], 'Popularity': [16]}
#                        Name  Popularity
# 0  Noble St & Milwaukee Ave          16
# name='Noble St & Milwaukee Ave'
# C=370    Chicago
# 370    Chicago
# 25     Chicago
# 25     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.90068
# longitude=-87.6626
#
# i=30
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 22)}
# Most recent date: 2013-06-28
# names=['Ashland Ave & Augusta Blvd', 'Ashland Ave & Augusta Blvd']
# unique_names=['Ashland Ave & Augusta Blvd']
# {'Name': ['Ashland Ave & Augusta Blvd'], 'Popularity': [16]}
#                          Name  Popularity
# 0  Ashland Ave & Augusta Blvd          16
# name='Ashland Ave & Augusta Blvd'
# C=18    Chicago
# 18    Chicago
# 26    Chicago
# 26    Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.899643
# longitude=-87.6677
#
# i=31
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 22)}
# Most recent date: 2013-06-28
# names=['Franklin St & Chicago Ave', 'Franklin St & Chicago Ave']
# unique_names=['Franklin St & Chicago Ave']
# {'Name': ['Franklin St & Chicago Ave'], 'Popularity': [16]}
#                         Name  Popularity
# 0  Franklin St & Chicago Ave          16
# name='Franklin St & Chicago Ave'
# C=206    Chicago
# 206    Chicago
# 27     Chicago
# 27     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.896789014999996
# longitude=-87.63563564625
#
# i=32
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 21), datetime.date(2013, 6, 22)}
# Most recent date: 2013-06-28
# names=['Racine Ave & Congress Pkwy', 'Racine Ave & Congress Pkwy']
# unique_names=['Racine Ave & Congress Pkwy']
# {'Name': ['Racine Ave & Congress Pkwy'], 'Popularity': [16]}
#                          Name  Popularity
# 0  Racine Ave & Congress Pkwy          16
# name='Racine Ave & Congress Pkwy'
# C=409    Chicago
# 409    Chicago
# 28     Chicago
# 28     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.87464
# longitude=-87.65703
#
# i=33
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 22), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['State St & Van Buren St', 'State St & Van Buren St']
# unique_names=['State St & Van Buren St']
# {'Name': ['State St & Van Buren St'], 'Popularity': [16]}
#                       Name  Popularity
# 0  State St & Van Buren St          16
# name='State St & Van Buren St'
# C=485    Chicago
# 485    Chicago
# 29     Chicago
# 29     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.877181
# longitude=-87.627844
#
# i=34
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 22), datetime.date(2013, 6, 27)}
# Most recent date: 2013-06-28
# names=['Cannon Dr & Fullerton Ave', 'Cannon Dr & Fullerton Ave']
# unique_names=['Cannon Dr & Fullerton Ave']
# {'Name': ['Cannon Dr & Fullerton Ave'], 'Popularity': [16]}
#                         Name  Popularity
# 0  Cannon Dr & Fullerton Ave          16
# name='Cannon Dr & Fullerton Ave'
# C=83    Chicago
# 83    Chicago
# 30    Chicago
# 30    Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.926755990937494
# longitude=-87.6344288081
#
# i=35
#
# Online Dates: {datetime.date(2013, 6, 22), datetime.date(2013, 8, 5)}
# Most recent date: 2013-08-05
# names=['Streeter Dr & Grand Ave', 'Streeter Dr & Grand Ave', 'Streeter Dr & Illinois St', 'Streeter Dr & Illinois St', 'Streeter Dr & Grand Ave', 'Streeter Dr & Grand Ave', 'Streeter Dr & Grand Ave', 'Streeter Dr & Grand Ave']
# unique_names=['Streeter Dr & Grand Ave', 'Streeter Dr & Illinois St']
# {'Name': ['Streeter Dr & Grand Ave', 'Streeter Dr & Illinois St'], 'Popularity': [10, 6]}
#                         Name  Popularity
# 0    Streeter Dr & Grand Ave          10
# 1  Streeter Dr & Illinois St           6
# name='Streeter Dr & Grand Ave'
# C=495    Chicago
# 495    Chicago
# 31     Chicago
# 31     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.89182537500001
# longitude=-87.61210187500001
#
# i=36
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 24), datetime.date(2013, 6, 15)}
# Most recent date: 2013-06-28
# names=['Franklin St & Jackson Blvd', 'Franklin St & Jackson Blvd']
# unique_names=['Franklin St & Jackson Blvd']
# {'Name': ['Franklin St & Jackson Blvd'], 'Popularity': [16]}
#                          Name  Popularity
# 0  Franklin St & Jackson Blvd          16
# name='Franklin St & Jackson Blvd'
# C=207    Chicago
# 207    Chicago
# 32     Chicago
# 32     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.8777079644875
# longitude=-87.6353211226
#
# i=37
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 16), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Dearborn St & Adams St', 'Dearborn St & Adams St']
# unique_names=['Dearborn St & Adams St']
# {'Name': ['Dearborn St & Adams St'], 'Popularity': [16]}
#                      Name  Popularity
# 0  Dearborn St & Adams St          16
# name='Dearborn St & Adams St'
# C=33     Chicago
# 33     Chicago
# 171    Chicago
# 171    Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.8793563148375
# longitude=-87.6297910345375
#
# i=38
#
# Online Dates: {datetime.date(2015, 4, 18), datetime.date(2013, 6, 25)}
# Most recent date: 2015-04-18
# names=['Clark St & Lake St', 'Clark St & Lake St', 'Clark St & Lake St', 'Clark St & Lake St', 'Clark St & Lake St', 'Clark St & Lake St']
# unique_names=['Clark St & Lake St']
# {'Name': ['Clark St & Lake St'], 'Popularity': [12]}
#                  Name  Popularity
# 0  Clark St & Lake St          12
# name='Clark St & Lake St'
# C=34     Chicago
# 34     Chicago
# 113    Chicago
# 113    Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.886020857955
# longitude=-87.63087604973333
#
# i=39
#
# Online Dates: {datetime.date(2015, 4, 18), datetime.date(2013, 6, 25)}
# Most recent date: 2015-04-18
# names=['Wabash Ave & Adams St', 'Wabash Ave & Adams St', 'Wabash Ave & Adams St', 'Wabash Ave & Adams St', 'Wabash Ave & Adams St', 'Wabash Ave & Adams St']
# unique_names=['Wabash Ave & Adams St']
# {'Name': ['Wabash Ave & Adams St'], 'Popularity': [12]}
#                     Name  Popularity
# 0  Wabash Ave & Adams St          12
# name='Wabash Ave & Adams St'
# C=35     Chicago
# 35     Chicago
# 509    Chicago
# 509    Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.87947229205834
# longitude=-87.62568867431666
#
# i=40
#
# Online Dates: {datetime.date(2015, 4, 25), datetime.date(2013, 6, 25)}
# Most recent date: 2015-04-25
# names=['LaSalle St & Adams St', 'LaSalle St & Adams St', 'LaSalle St & Adams St', 'LaSalle St & Adams St', 'LaSalle St & Adams St', 'LaSalle St & Adams St']
# unique_names=['LaSalle St & Adams St']
# {'Name': ['LaSalle St & Adams St'], 'Popularity': [12]}
#                     Name  Popularity
# 0  LaSalle St & Adams St          12
# name='LaSalle St & Adams St'
# C=36     Chicago
# 36     Chicago
# 300    Chicago
# 300    Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.87934430891
# longitude=-87.63198518355
#
# i=41
#
# Online Dates: {datetime.date(2015, 4, 25), datetime.date(2013, 6, 25)}
# Most recent date: 2015-04-25
# names=['Federal St & Polk St', 'Federal St & Polk St', 'Federal St & Polk St', 'Federal St & Polk St', 'Federal St & Polk St', 'Federal St & Polk St']
# unique_names=['Federal St & Polk St']
# {'Name': ['Federal St & Polk St'], 'Popularity': [12]}
#                    Name  Popularity
# 0  Federal St & Polk St          12
# name='Federal St & Polk St'
# C=37     Chicago
# 37     Chicago
# 200    Chicago
# 200    Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.87207769214166
# longitude=-87.62954380881668
#
# i=42
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 18), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Wabash Ave & Cermak Rd', 'Wabash Ave & Cermak Rd']
# unique_names=['Wabash Ave & Cermak Rd']
# {'Name': ['Wabash Ave & Cermak Rd'], 'Popularity': [16]}
#                      Name  Popularity
# 0  Wabash Ave & Cermak Rd          16
# name='Wabash Ave & Cermak Rd'
# C=38     Chicago
# 38     Chicago
# 510    Chicago
# 510    Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.85277394
# longitude=-87.6262002725
#
# i=43
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 16), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Michigan Ave & Washington St', 'Michigan Ave & Washington St']
# unique_names=['Michigan Ave & Washington St']
# {'Name': ['Michigan Ave & Washington St'], 'Popularity': [16]}
#                            Name  Popularity
# 0  Michigan Ave & Washington St          16
# name='Michigan Ave & Washington St'
# C=346    Chicago
# 346    Chicago
# 39     Chicago
# 39     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.883892798225006
# longitude=-87.62464912261251
#
# i=44
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 16), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['State St & Randolph St', 'State St & Randolph St']
# unique_names=['State St & Randolph St']
# {'Name': ['State St & Randolph St'], 'Popularity': [16]}
#                      Name  Popularity
# 0  State St & Randolph St          16
# name='State St & Randolph St'
# C=484    Chicago
# 484    Chicago
# 40     Chicago
# 40     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.884730175075
# longitude=-87.62773362365
#
# i=45
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 16), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Michigan Ave & Congress Pkwy', 'Michigan Ave & Congress Pkwy']
# unique_names=['Michigan Ave & Congress Pkwy']
# {'Name': ['Michigan Ave & Congress Pkwy'], 'Popularity': [16]}
#                            Name  Popularity
# 0  Michigan Ave & Congress Pkwy          16
# name='Michigan Ave & Congress Pkwy'
# C=340    Chicago
# 340    Chicago
# 41     Chicago
# 41     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.876198650000006
# longitude=-87.62442784
#
# i=46
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 14), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Wells St & Walton St', 'Wells St & Walton St']
# unique_names=['Wells St & Walton St']
# {'Name': ['Wells St & Walton St'], 'Popularity': [16]}
#                    Name  Popularity
# 0  Wells St & Walton St          16
# name='Wells St & Walton St'
# C=526    Chicago
# 526    Chicago
# 42     Chicago
# 42     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.899930008750005
# longitude=-87.63443006124999
#
# i=47
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 18), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['State St & Kinzie St', 'State St & Kinzie St']
# unique_names=['State St & Kinzie St']
# {'Name': ['State St & Kinzie St'], 'Popularity': [16]}
#                    Name  Popularity
# 0  State St & Kinzie St          16
# name='State St & Kinzie St'
# C=481    Chicago
# 481    Chicago
# 43     Chicago
# 43     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.88918175
# longitude=-87.6277135
#
# i=48
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 16), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Larrabee St & Kingsbury St', 'Larrabee St & Kingsbury St']
# unique_names=['Larrabee St & Kingsbury St']
# {'Name': ['Larrabee St & Kingsbury St'], 'Popularity': [16]}
#                          Name  Popularity
# 0  Larrabee St & Kingsbury St          16
# name='Larrabee St & Kingsbury St'
# C=295    Chicago
# 295    Chicago
# 44     Chicago
# 44     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.897764
# longitude=-87.642884
#
# i=49
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 16), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Dearborn St & Monroe St', 'Dearborn St & Monroe St']
# unique_names=['Dearborn St & Monroe St']
# {'Name': ['Dearborn St & Monroe St'], 'Popularity': [16]}
#                       Name  Popularity
# 0  Dearborn St & Monroe St          16
# name='Dearborn St & Monroe St'
# C=173    Chicago
# 173    Chicago
# 45     Chicago
# 45     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.881319841875
# longitude=-87.6295209299125
#
# i=50
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 16), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Clark St & Congress Pkwy', 'Clark St & Congress Pkwy']
# unique_names=['Clark St & Congress Pkwy']
# {'Name': ['Clark St & Congress Pkwy'], 'Popularity': [16]}
#                        Name  Popularity
# 0  Clark St & Congress Pkwy          16
# name='Clark St & Congress Pkwy'
# C=108    Chicago
# 108    Chicago
# 46     Chicago
# 46     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.8759327106875
# longitude=-87.6305845969375
#
# i=51
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 17), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Clark St & Randolph St', 'Clark St & Randolph St']
# unique_names=['Clark St & Randolph St']
# {'Name': ['Clark St & Randolph St'], 'Popularity': [16]}
#                      Name  Popularity
# 0  Clark St & Randolph St          16
# name='Clark St & Randolph St'
# C=119    Chicago
# 119    Chicago
# 47     Chicago
# 47     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.884576201
# longitude=-87.63188992125
#
# i=52
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 17), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Michigan Ave & Lake St', 'Michigan Ave & Lake St']
# unique_names=['Michigan Ave & Lake St']
# {'Name': ['Michigan Ave & Lake St'], 'Popularity': [16]}
#                      Name  Popularity
# 0  Michigan Ave & Lake St          16
# name='Michigan Ave & Lake St'
# C=342    Chicago
# 342    Chicago
# 48     Chicago
# 48     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.88602826499999
# longitude=-87.62413854249999
#
# i=53
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 17), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Wells St & Erie St', 'Wells St & Erie St']
# unique_names=['Wells St & Erie St']
# {'Name': ['Wells St & Erie St'], 'Popularity': [6]}
#                  Name  Popularity
# 0  Wells St & Erie St           6
# name='Wells St & Erie St'
# C=524    Chicago
# 524    Chicago
# 49     Chicago
# 49     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.894411749999996
# longitude=-87.633825875
#
# i=54
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 17), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Ogden Ave & Chicago Ave', 'Ogden Ave & Chicago Ave']
# unique_names=['Ogden Ave & Chicago Ave']
# {'Name': ['Ogden Ave & Chicago Ave'], 'Popularity': [16]}
#                       Name  Popularity
# 0  Ogden Ave & Chicago Ave          16
# name='Ogden Ave & Chicago Ave'
# C=376    Chicago
# 376    Chicago
# 50     Chicago
# 50     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.89636240225
# longitude=-87.6540612366125
#
# i=55
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 17), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Halsted St & James M Rochford St', 'Halsted St & James M Rochford St']
# unique_names=['Halsted St & James M Rochford St']
# {'Name': ['Halsted St & James M Rochford St'], 'Popularity': [6]}
#                                Name  Popularity
# 0  Halsted St & James M Rochford St           6
# name='Halsted St & James M Rochford St'
# C=237    Chicago
# 237    Chicago
# 51     Chicago
# 51     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.866775374999996
# longitude=-87.64786975
#
# i=56
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 17), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Desplaines St & Kinzie St', 'Desplaines St & Kinzie St']
# unique_names=['Desplaines St & Kinzie St']
# {'Name': ['Desplaines St & Kinzie St'], 'Popularity': [16]}
#                         Name  Popularity
# 0  Desplaines St & Kinzie St          16
# name='Desplaines St & Kinzie St'
# C=175    Chicago
# 175    Chicago
# 52     Chicago
# 52     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.88871603449999
# longitude=-87.6444478691625
#
# i=57
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 17), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Clinton St & Roosevelt Rd', 'Clinton St & Roosevelt Rd']
# unique_names=['Clinton St & Roosevelt Rd']
# {'Name': ['Clinton St & Roosevelt Rd'], 'Popularity': [16]}
#                         Name  Popularity
# 0  Clinton St & Roosevelt Rd          16
# name='Clinton St & Roosevelt Rd'
# C=132    Chicago
# 132    Chicago
# 53     Chicago
# 53     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.867117807812505
# longitude=-87.6410879649125
#
# i=58
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 18), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Ashland Ave & Armitage Ave', 'Ashland Ave & Armitage Ave']
# unique_names=['Ashland Ave & Armitage Ave']
# {'Name': ['Ashland Ave & Armitage Ave'], 'Popularity': [2]}
#                          Name  Popularity
# 0  Ashland Ave & Armitage Ave           2
# name='Ashland Ave & Armitage Ave'
# C=329    Chicago
# 329    Chicago
# 54     Chicago
# 54     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.91624723375
# longitude=-87.668884
#
# i=59
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 18), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Wabash Ave & Roosevelt Rd', 'Wabash Ave & Roosevelt Rd']
# unique_names=['Wabash Ave & Roosevelt Rd']
# {'Name': ['Wabash Ave & Roosevelt Rd'], 'Popularity': [16]}
#                         Name  Popularity
# 0  Wabash Ave & Roosevelt Rd          16
# name='Wabash Ave & Roosevelt Rd'
# C=512    Chicago
# 512    Chicago
# 55     Chicago
# 55     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.86722025
# longitude=-87.62596025125
#
# i=60
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 18), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Dayton St & North Ave', 'Dayton St & North Ave']
# unique_names=['Dayton St & North Ave']
# {'Name': ['Dayton St & North Ave'], 'Popularity': [16]}
#                     Name  Popularity
# 0  Dayton St & North Ave          16
# name='Dayton St & North Ave'
# C=169    Chicago
# 169    Chicago
# 56     Chicago
# 56     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.9105780268625
# longitude=-87.6494219386
#
# i=61
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 18), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Wood St & Milwaukee Ave', 'Wood St & Milwaukee Ave']
# unique_names=['Wood St & Milwaukee Ave']
# {'Name': ['Wood St & Milwaukee Ave'], 'Popularity': [16]}
#                       Name  Popularity
# 0  Wood St & Milwaukee Ave          16
# name='Wood St & Milwaukee Ave'
# C=553    Chicago
# 553    Chicago
# 57     Chicago
# 57     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.907655
# longitude=-87.672552
#
# i=62
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 18), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['McCormick Place', 'McCormick Place']
# unique_names=['McCormick Place']
# {'Name': ['McCormick Place'], 'Popularity': [16]}
#               Name  Popularity
# 0  McCormick Place          16
# name='McCormick Place'
# C=336    Chicago
# 336    Chicago
# 58     Chicago
# 58     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.8513751491125
# longitude=-87.61883469361248
#
# i=66
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 20), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Clinton St & Lake St', 'Clinton St & Lake St']
# unique_names=['Clinton St & Lake St']
# {'Name': ['Clinton St & Lake St'], 'Popularity': [16]}
#                    Name  Popularity
# 0  Clinton St & Lake St          16
# name='Clinton St & Lake St'
# C=129    Chicago
# 129    Chicago
# 59     Chicago
# 59     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.8856887775
# longitude=-87.64158649125
#
# i=67
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 20), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Sheffield Ave & Fullerton Ave', 'Sheffield Ave & Fullerton Ave']
# unique_names=['Sheffield Ave & Fullerton Ave']
# {'Name': ['Sheffield Ave & Fullerton Ave'], 'Popularity': [16]}
#                             Name  Popularity
# 0  Sheffield Ave & Fullerton Ave          16
# name='Sheffield Ave & Fullerton Ave'
# C=441    Chicago
# 441    Chicago
# 60     Chicago
# 60     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.925601895237506
# longitude=-87.6537080352875
#
# i=68
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 24), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Clinton St & Tilden St', 'Clinton St & Tilden St']
# unique_names=['Clinton St & Tilden St']
# {'Name': ['Clinton St & Tilden St'], 'Popularity': [16]}
#                      Name  Popularity
# 0  Clinton St & Tilden St          16
# name='Clinton St & Tilden St'
# C=133    Chicago
# 133    Chicago
# 61     Chicago
# 61     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.875885
# longitude=-87.640795
#
# i=69
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 24), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Damen Ave & Pierce Ave', 'Damen Ave & Pierce Ave']
# unique_names=['Damen Ave & Pierce Ave']
# {'Name': ['Damen Ave & Pierce Ave'], 'Popularity': [16]}
#                      Name  Popularity
# 0  Damen Ave & Pierce Ave          16
# name='Damen Ave & Pierce Ave'
# C=166    Chicago
# 166    Chicago
# 62     Chicago
# 62     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.909396008312505
# longitude=-87.67769193865
#
# i=71
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 24), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Morgan St & Lake St', 'Morgan St & Lake St']
# unique_names=['Morgan St & Lake St']
# {'Name': ['Morgan St & Lake St'], 'Popularity': [16]}
#                   Name  Popularity
# 0  Morgan St & Lake St          16
# name='Morgan St & Lake St'
# C=366    Chicago
# 366    Chicago
# 63     Chicago
# 63     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.8854832709875
# longitude=-87.65230487705
#
# i=72
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 24), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['State St & 16th St', 'State St & 16th St']
# unique_names=['State St & 16th St']
# {'Name': ['State St & 16th St'], 'Popularity': [6]}
#                  Name  Popularity
# 0  State St & 16th St           6
# name='State St & 16th St'
# C=505    Chicago
# 505    Chicago
# 64     Chicago
# 64     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.8602855175
# longitude=-87.62653157124998
#
# i=73
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 27), datetime.date(2013, 6, 25)}
# Most recent date: 2013-06-28
# names=['Jefferson St & Monroe St', 'Jefferson St & Monroe St']
# unique_names=['Jefferson St & Monroe St']
# {'Name': ['Jefferson St & Monroe St'], 'Popularity': [16]}
#                        Name  Popularity
# 0  Jefferson St & Monroe St          16
# name='Jefferson St & Monroe St'
# C=250    Chicago
# 250    Chicago
# 65     Chicago
# 65     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.880421999999996
# longitude=-87.642746
#
# i=74
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 26), datetime.date(2013, 6, 14)}
# Most recent date: 2013-06-28
# names=['Kingsbury St & Erie St', 'Kingsbury St & Erie St']
# unique_names=['Kingsbury St & Erie St']
# {'Name': ['Kingsbury St & Erie St'], 'Popularity': [16]}
#                      Name  Popularity
# 0  Kingsbury St & Erie St          16
# name='Kingsbury St & Erie St'
# C=272    Chicago
# 272    Chicago
# 66     Chicago
# 66     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.89386743125
# longitude=-87.64176356
#
# i=75
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 26), datetime.date(2013, 6, 15)}
# Most recent date: 2013-06-28
# names=['Canal St & Jackson Blvd', 'Canal St & Jackson Blvd']
# unique_names=['Canal St & Jackson Blvd']
# {'Name': ['Canal St & Jackson Blvd'], 'Popularity': [16]}
#                       Name  Popularity
# 0  Canal St & Jackson Blvd          16
# name='Canal St & Jackson Blvd'
# C=79    Chicago
# 79    Chicago
# 67    Chicago
# 67    Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.87805015125
# longitude=-87.64036401499999
#
# i=76
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 26), datetime.date(2013, 6, 24)}
# Most recent date: 2013-06-28
# names=['Lake Shore Dr & Monroe St', 'Lake Shore Dr & Monroe St']
# unique_names=['Lake Shore Dr & Monroe St']
# {'Name': ['Lake Shore Dr & Monroe St'], 'Popularity': [16]}
#                         Name  Popularity
# 0  Lake Shore Dr & Monroe St          16
# name='Lake Shore Dr & Monroe St'
# C=284    Chicago
# 284    Chicago
# 68     Chicago
# 68     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.880969500000006
# longitude=-87.616771375
#
# i=77
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 26), datetime.date(2013, 6, 15)}
# Most recent date: 2013-06-28
# names=['Clinton St & Madison St', 'Clinton St & Madison St']
# unique_names=['Clinton St & Madison St']
# {'Name': ['Clinton St & Madison St'], 'Popularity': [16]}
#                       Name  Popularity
# 0  Clinton St & Madison St          16
# name='Clinton St & Madison St'
# C=130    Chicago
# 130    Chicago
# 69     Chicago
# 69     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.882077100000004
# longitude=-87.6411188575
#
# i=80
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 26)}
# Most recent date: 2013-06-28
# names=['Aberdeen St & Madison St', 'Aberdeen St & Madison St']
# unique_names=['Aberdeen St & Madison St']
# {'Name': ['Aberdeen St & Madison St'], 'Popularity': [6]}
#                        Name  Popularity
# 0  Aberdeen St & Madison St           6
# name='Aberdeen St & Madison St'
# C=4     Chicago
# 4     Chicago
# 70    Chicago
# 70    Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.880967874999996
# longitude=-87.65499475
#
# i=81
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 13), datetime.date(2013, 6, 26)}
# Most recent date: 2013-06-28
# names=['Daley Center Plaza', 'Daley Center Plaza']
# unique_names=['Daley Center Plaza']
# {'Name': ['Daley Center Plaza'], 'Popularity': [16]}
#                  Name  Popularity
# 0  Daley Center Plaza          16
# name='Daley Center Plaza'
# C=149    Chicago
# 149    Chicago
# 71     Chicago
# 71     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.884305499999996
# longitude=-87.629767125
#
# i=84
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 26)}
# Most recent date: 2013-06-28
# names=['Green St & Milwaukee Ave', 'Green St & Milwaukee Ave']
# unique_names=['Green St & Milwaukee Ave']
# {'Name': ['Green St & Milwaukee Ave'], 'Popularity': [2]}
#                        Name  Popularity
# 0  Green St & Milwaukee Ave           2
# name='Green St & Milwaukee Ave'
# C=352    Chicago
# 352    Chicago
# 72     Chicago
# 72     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.891236125000006
# longitude=-87.64689000000001
#
# i=85
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 21), datetime.date(2013, 6, 26)}
# Most recent date: 2013-06-28
# names=['Michigan Ave & Oak St', 'Michigan Ave & Oak St']
# unique_names=['Michigan Ave & Oak St']
# {'Name': ['Michigan Ave & Oak St'], 'Popularity': [16]}
#                     Name  Popularity
# 0  Michigan Ave & Oak St          16
# name='Michigan Ave & Oak St'
# C=344    Chicago
# 344    Chicago
# 73     Chicago
# 73     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.90096034125
# longitude=-87.623776685
#
# i=86
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 26)}
# Most recent date: 2013-06-28
# names=['Eckhart Park', 'Eckhart Park']
# unique_names=['Eckhart Park']
# {'Name': ['Eckhart Park'], 'Popularity': [16]}
#            Name  Popularity
# 0  Eckhart Park          16
# name='Eckhart Park'
# C=186    Chicago
# 186    Chicago
# 74     Chicago
# 74     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.89637332375
# longitude=-87.6609838775
#
# i=87
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 26)}
# Most recent date: 2013-06-28
# names=['Racine Ave & Fullerton Ave', 'Racine Ave & Fullerton Ave']
# unique_names=['Racine Ave & Fullerton Ave']
# {'Name': ['Racine Ave & Fullerton Ave'], 'Popularity': [16]}
#                          Name  Popularity
# 0  Racine Ave & Fullerton Ave          16
# name='Racine Ave & Fullerton Ave'
# C=410    Chicago
# 410    Chicago
# 75     Chicago
# 75     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.925562632500004
# longitude=-87.6584042275
#
# i=88
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 27), datetime.date(2013, 6, 26)}
# Most recent date: 2013-06-28
# names=['May St & Randolph St', 'May St & Randolph St']
# unique_names=['May St & Randolph St']
# {'Name': ['May St & Randolph St'], 'Popularity': [12]}
#                    Name  Popularity
# 0  May St & Randolph St          12
# name='May St & Randolph St'
# C=412    Chicago
# 412    Chicago
# 76     Chicago
# 76     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.88399475
# longitude=-87.65597925
#
# i=89
#
# Online Dates: {datetime.date(2015, 5, 8), datetime.date(2013, 6, 26)}
# Most recent date: 2015-05-08
# names=['Financial Pl & Congress Pkwy', 'Financial Pl & Congress Pkwy', 'Financial Pl & Congress Pkwy', 'Financial Pl & Congress Pkwy', 'Financial Pl & Congress Pkwy', 'Financial Pl & Congress Pkwy']
# unique_names=['Financial Pl & Congress Pkwy']
# {'Name': ['Financial Pl & Congress Pkwy'], 'Popularity': [12]}
#                            Name  Popularity
# 0  Financial Pl & Congress Pkwy          12
# name='Financial Pl & Congress Pkwy'
# C=203    Chicago
# 203    Chicago
# 77     Chicago
# 77     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.87500910915667
# longitude=-87.63310584981666
#
# i=90
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 26), datetime.date(2013, 6, 16)}
# Most recent date: 2013-06-28
# names=['Millennium Park', 'Millennium Park']
# unique_names=['Millennium Park']
# {'Name': ['Millennium Park'], 'Popularity': [16]}
#               Name  Popularity
# 0  Millennium Park          16
# name='Millennium Park'
# C=350    Chicago
# 350    Chicago
# 78     Chicago
# 78     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.881031737499995
# longitude=-87.62408428
#
# i=91
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 26), datetime.date(2013, 6, 15)}
# Most recent date: 2013-06-28
# names=['Clinton St & Washington Blvd', 'Clinton St & Washington Blvd']
# unique_names=['Clinton St & Washington Blvd']
# {'Name': ['Clinton St & Washington Blvd'], 'Popularity': [16]}
#                            Name  Popularity
# 0  Clinton St & Washington Blvd          16
# name='Clinton St & Washington Blvd'
# C=134    Chicago
# 134    Chicago
# 79     Chicago
# 79     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.88338
# longitude=-87.64116999999999
#
# i=92
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 27), datetime.date(2013, 6, 26)}
# Most recent date: 2013-06-28
# names=['Carpenter St & Huron St', 'Carpenter St & Huron St']
# unique_names=['Carpenter St & Huron St']
# {'Name': ['Carpenter St & Huron St'], 'Popularity': [16]}
#                       Name  Popularity
# 0  Carpenter St & Huron St          16
# name='Carpenter St & Huron St'
# C=80    Chicago
# 80    Chicago
# 84    Chicago
# 84    Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.894556
# longitude=-87.653449
#
# i=93
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 27)}
# Most recent date: 2013-06-28
# names=['Sheffield Ave & Willow St', 'Sheffield Ave & Willow St']
# unique_names=['Sheffield Ave & Willow St']
# {'Name': ['Sheffield Ave & Willow St'], 'Popularity': [16]}
#                         Name  Popularity
# 0  Sheffield Ave & Willow St          16
# name='Sheffield Ave & Willow St'
# C=446    Chicago
# 446    Chicago
# 81     Chicago
# 81     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.913688
# longitude=-87.652855
#
# i=94
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2013, 6, 22), datetime.date(2013, 6, 27)}
# Most recent date: 2013-06-28
# names=['Lincoln Ave & Armitage Ave', 'Lincoln Ave & Armitage Ave']
# unique_names=['Lincoln Ave & Armitage Ave']
# {'Name': ['Lincoln Ave & Armitage Ave'], 'Popularity': [2]}
#                          Name  Popularity
# 0  Lincoln Ave & Armitage Ave           2
# name='Lincoln Ave & Armitage Ave'
# C=103    Chicago
# 103    Chicago
# 82     Chicago
# 82     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.918301875
# longitude=-87.63651125
#
# i=95
#
# Online Dates: {datetime.date(2015, 5, 7), datetime.date(2013, 6, 27)}
# Most recent date: 2015-05-07
# names=['Stony Island Ave & 64th St', 'Stony Island Ave & 64th St', 'Stony Island Ave & 64th St', 'Stony Island Ave & 64th St', 'Stony Island Ave & 64th St', 'Stony Island Ave & 64th St']
# unique_names=['Stony Island Ave & 64th St']
# {'Name': ['Stony Island Ave & 64th St'], 'Popularity': [12]}
#                          Name  Popularity
# 0  Stony Island Ave & 64th St          12
# name='Stony Island Ave & 64th St'
# C=489    Chicago
# 489    Chicago
# 83     Chicago
# 83     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.77870064188
# longitude=-87.58678768298334
#
# i=96
#
# Online Dates: {datetime.date(2013, 6, 28), datetime.date(2015, 4, 25)}
# Most recent date: 2015-04-25
# ...
# longitude=-87.69872999999998
#
# i=602
#
# Online Dates: {datetime.date(2016, 7, 8), datetime.date(2016, 6, 14)}
# Most recent date: 2016-07-08
# names=['Central St & Girard Ave', 'Central St & Girard Ave', 'Central St & Girard Ave', 'Central St & Girard Ave']
# unique_names=['Central St & Girard Ave']
# {'Name': ['Central St & Girard Ave'], 'Popularity': [8]}
#                       Name  Popularity
# 0  Central St & Girard Ave           8
# name='Central St & Girard Ave'
# C=560    Evanston
# 560    Evanston
# 561    Evanston
# 561    Evanston
# Name: City, dtype: object
# city='Evanston'
# latitude=42.064077499999996
# longitude=-87.68600950000001
#
# i=603
#
# Online Dates: {datetime.date(2016, 7, 1), datetime.date(2016, 6, 14)}
# Most recent date: 2016-07-01
# names=['Chicago Ave & Sheridan Rd', 'Chicago Ave & Sheridan Rd', 'Chicago Ave & Sheridan Rd', 'Chicago Ave & Sheridan Rd']
# unique_names=['Chicago Ave & Sheridan Rd']
# {'Name': ['Chicago Ave & Sheridan Rd'], 'Popularity': [8]}
#                         Name  Popularity
# 0  Chicago Ave & Sheridan Rd           8
# name='Chicago Ave & Sheridan Rd'
# C=562    Evanston
# 562    Evanston
# 562    Evanston
# 562    Evanston
# Name: City, dtype: object
# city='Evanston'
# latitude=42.050491
# longitude=-87.677821
#
# i=604
#
# Online Dates: {datetime.date(2016, 7, 1), datetime.date(2016, 6, 14)}
# Most recent date: 2016-07-01
# names=['Sheridan Rd & Noyes St (NU)', 'Sheridan Rd & Noyes St (NU)', 'Sheridan Rd & Noyes St (NU)', 'Sheridan Rd & Noyes St (NU)']
# unique_names=['Sheridan Rd & Noyes St (NU)']
# {'Name': ['Sheridan Rd & Noyes St (NU)'], 'Popularity': [8]}
#                           Name  Popularity
# 0  Sheridan Rd & Noyes St (NU)           8
# name='Sheridan Rd & Noyes St (NU)'
# C=566    Evanston
# 566    Evanston
# 563    Evanston
# 563    Evanston
# Name: City, dtype: object
# city='Evanston'
# latitude=42.058239
# longitude=-87.677432
#
# i=605
#
# Online Dates: {datetime.date(2016, 7, 1), datetime.date(2016, 6, 14)}
# Most recent date: 2016-07-01
# names=['University Library (NU)', 'University Library (NU)', 'University Library (NU)', 'University Library (NU)']
# unique_names=['University Library (NU)']
# {'Name': ['University Library (NU)'], 'Popularity': [8]}
#                       Name  Popularity
# 0  University Library (NU)           8
# name='University Library (NU)'
# C=567    Evanston
# 567    Evanston
# 564    Evanston
# 564    Evanston
# Name: City, dtype: object
# city='Evanston'
# latitude=42.052939
# longitude=-87.673447
#
# i=606
#
# Online Dates: {datetime.date(2016, 6, 23), datetime.date(2016, 7, 6)}
# Most recent date: 2016-07-06
# names=['Forest Ave & Chicago Ave', 'Forest Ave & Chicago Ave', 'Forest Ave & Chicago Ave', 'Forest Ave & Chicago Ave']
# unique_names=['Forest Ave & Chicago Ave']
# {'Name': ['Forest Ave & Chicago Ave'], 'Popularity': [8]}
#                        Name  Popularity
# 0  Forest Ave & Chicago Ave           8
# name='Forest Ave & Chicago Ave'
# C=572    Oak Park
# 572    Oak Park
# 565    Oak Park
# 565    Oak Park
# Name: City, dtype: object
# city='Oak Park'
# latitude=41.894213
# longitude=-87.80029350000001
#
# i=607
#
# Online Dates: {datetime.date(2016, 6, 23), datetime.date(2016, 6, 30)}
# Most recent date: 2016-06-30
# names=['Cuyler Ave & Augusta St', 'Cuyler Ave & Augusta St', 'Cuyler Ave & Augusta St', 'Cuyler Ave & Augusta St', 'Cuyler Ave & Augusta St', 'Cuyler Ave & Augusta St']
# unique_names=['Cuyler Ave & Augusta St']
# {'Name': ['Cuyler Ave & Augusta St'], 'Popularity': [10]}
#                       Name  Popularity
# 0  Cuyler Ave & Augusta St          10
# name='Cuyler Ave & Augusta St'
# C=569    Oak Park
# 569    Oak Park
# 566    Oak Park
# 566    Oak Park
# Name: City, dtype: object
# city='Oak Park'
# latitude=41.898168
# longitude=-87.783055
#
# i=608
#
# Online Dates: {datetime.date(2016, 6, 23), datetime.date(2016, 6, 30)}
# Most recent date: 2016-06-30
# names=['Humphrey Ave & Ontario St', 'Humphrey Ave & Ontario St', 'Humphrey Ave & Ontario St', 'Humphrey Ave & Ontario St', 'Humphrey Ave & Ontario St', 'Humphrey Ave & Ontario St']
# unique_names=['Humphrey Ave & Ontario St']
# {'Name': ['Humphrey Ave & Ontario St'], 'Popularity': [10]}
#                         Name  Popularity
# 0  Humphrey Ave & Ontario St          10
# name='Humphrey Ave & Ontario St'
# C=574    Oak Park
# 574    Oak Park
# 567    Oak Park
# 567    Oak Park
# Name: City, dtype: object
# city='Oak Park'
# latitude=41.89039419999999
# longitude=-87.7774176
#
# i=609
#
# Online Dates: {datetime.date(2016, 6, 23), datetime.date(2016, 6, 30)}
# Most recent date: 2016-06-30
# names=['Forest Ave & Lake St', 'Forest Ave & Lake St', 'Forest Ave & Lake St', 'Forest Ave & Lake St', 'Forest Ave & Lake St', 'Forest Ave & Lake St']
# unique_names=['Forest Ave & Lake St']
# {'Name': ['Forest Ave & Lake St'], 'Popularity': [10]}
#                    Name  Popularity
# 0  Forest Ave & Lake St          10
# name='Forest Ave & Lake St'
# C=573    Oak Park
# 573    Oak Park
# 568    Oak Park
# 568    Oak Park
# Name: City, dtype: object
# city='Oak Park'
# latitude=41.888909999999996
# longitude=-87.800255
#
# i=610
#
# Online Dates: {datetime.date(2016, 6, 23), datetime.date(2016, 6, 30)}
# Most recent date: 2016-06-30
# names=['Marion St & South Blvd', 'Marion St & South Blvd', 'Marion St & South Blvd', 'Marion St & South Blvd', 'Marion St & South Blvd', 'Marion St & South Blvd']
# unique_names=['Marion St & South Blvd']
# {'Name': ['Marion St & South Blvd'], 'Popularity': [10]}
#                      Name  Popularity
# 0  Marion St & South Blvd          10
# name='Marion St & South Blvd'
# C=577    Oak Park
# 577    Oak Park
# 569    Oak Park
# 569    Oak Park
# Name: City, dtype: object
# city='Oak Park'
# latitude=41.88680999999999
# longitude=-87.80287
#
# i=611
#
# Online Dates: {datetime.date(2016, 6, 23), datetime.date(2016, 6, 30)}
# Most recent date: 2016-06-30
# names=['Oak Park Ave & South Blvd', 'Oak Park Ave & South Blvd', 'Oak Park Ave & South Blvd', 'Oak Park Ave & South Blvd', 'Oak Park Ave & South Blvd', 'Oak Park Ave & South Blvd']
# unique_names=['Oak Park Ave & South Blvd']
# {'Name': ['Oak Park Ave & South Blvd'], 'Popularity': [10]}
#                         Name  Popularity
# 0  Oak Park Ave & South Blvd          10
# name='Oak Park Ave & South Blvd'
# C=579    Oak Park
# 579    Oak Park
# 570    Oak Park
# 570    Oak Park
# Name: City, dtype: object
# city='Oak Park'
# latitude=41.886923
# longitude=-87.793899
#
# i=612
#
# Online Dates: {datetime.date(2016, 6, 23), datetime.date(2016, 7, 27)}
# Most recent date: 2016-07-27
# names=['Ridgeland Ave & Lake St', 'Ridgeland Ave & Lake St', 'Ridgeland Ave & Lake St', 'Ridgeland Ave & Lake St']
# unique_names=['Ridgeland Ave & Lake St']
# {'Name': ['Ridgeland Ave & Lake St'], 'Popularity': [8]}
#                       Name  Popularity
# 0  Ridgeland Ave & Lake St           8
# name='Ridgeland Ave & Lake St'
# C=580    Oak Park
# 580    Oak Park
# 571    Oak Park
# 571    Oak Park
# Name: City, dtype: object
# city='Oak Park'
# latitude=41.888085
# longitude=-87.785236
#
# i=613
#
# Online Dates: {datetime.date(2016, 6, 28), datetime.date(2016, 6, 23)}
# Most recent date: 2016-06-28
# names=['Wisconsin Ave & Madison St', 'Wisconsin Ave & Madison St', 'Wisconsin Ave & Madison St', 'Wisconsin Ave & Madison St', 'Wisconsin Ave & Madison St', 'Wisconsin Ave & Madison St']
# unique_names=['Wisconsin Ave & Madison St']
# {'Name': ['Wisconsin Ave & Madison St'], 'Popularity': [8]}
#                          Name  Popularity
# 0  Wisconsin Ave & Madison St           8
# name='Wisconsin Ave & Madison St'
# C=581    Oak Park
# 581    Oak Park
# 572    Oak Park
# 572    Oak Park
# Name: City, dtype: object
# city='Oak Park'
# latitude=41.879850000000005
# longitude=-87.8025742
#
# i=614
#
# Online Dates: {datetime.date(2016, 6, 28), datetime.date(2016, 6, 23)}
# Most recent date: 2016-06-28
# names=['East Ave & Madison St', 'East Ave & Madison St', 'East Ave & Madison St', 'East Ave & Madison St', 'East Ave & Madison St', 'East Ave & Madison St']
# unique_names=['East Ave & Madison St']
# {'Name': ['East Ave & Madison St'], 'Popularity': [10]}
#                     Name  Popularity
# 0  East Ave & Madison St          10
# name='East Ave & Madison St'
# C=571    Oak Park
# 571    Oak Park
# 573    Oak Park
# 573    Oak Park
# Name: City, dtype: object
# city='Oak Park'
# latitude=41.880113
# longitude=-87.78924700000002
#
# i=615
#
# Online Dates: {datetime.date(2016, 6, 28), datetime.date(2016, 6, 23)}
# Most recent date: 2016-06-28
# names=['Lombard Ave & Madison St', 'Lombard Ave & Madison St', 'Lombard Ave & Madison St', 'Lombard Ave & Madison St', 'Lombard Ave & Madison St', 'Lombard Ave & Madison St']
# unique_names=['Lombard Ave & Madison St']
# {'Name': ['Lombard Ave & Madison St'], 'Popularity': [10]}
#                        Name  Popularity
# 0  Lombard Ave & Madison St          10
# name='Lombard Ave & Madison St'
# C=576    Oak Park
# 576    Oak Park
# 574    Oak Park
# 574    Oak Park
# Name: City, dtype: object
# city='Oak Park'
# latitude=41.879810000000006
# longitude=-87.77942499999999
#
# i=616
#
# Online Dates: {datetime.date(2016, 6, 23), datetime.date(2016, 6, 27)}
# Most recent date: 2016-06-27
# names=['Oak Park Ave & Harrison St', 'Oak Park Ave & Harrison St', 'Oak Park Ave & Harrison St', 'Oak Park Ave & Harrison St', 'Oak Park Ave & Harrison St', 'Oak Park Ave & Harrison St']
# unique_names=['Oak Park Ave & Harrison St']
# {'Name': ['Oak Park Ave & Harrison St'], 'Popularity': [10]}
#                          Name  Popularity
# 0  Oak Park Ave & Harrison St          10
# name='Oak Park Ave & Harrison St'
# C=578    Oak Park
# 578    Oak Park
# 575    Oak Park
# 575    Oak Park
# Name: City, dtype: object
# city='Oak Park'
# latitude=41.87298700000001
# longitude=-87.793945
#
# i=617
#
# Online Dates: {datetime.date(2016, 6, 23), datetime.date(2016, 6, 27)}
# Most recent date: 2016-06-27
# names=['East Ave & Garfield St', 'East Ave & Garfield St', 'East Ave & Garfield St', 'East Ave & Garfield St', 'East Ave & Garfield St', 'East Ave & Garfield St']
# unique_names=['East Ave & Garfield St']
# {'Name': ['East Ave & Garfield St'], 'Popularity': [10]}
#                      Name  Popularity
# 0  East Ave & Garfield St          10
# name='East Ave & Garfield St'
# C=570    Oak Park
# 570    Oak Park
# 576    Oak Park
# 576    Oak Park
# Name: City, dtype: object
# city='Oak Park'
# latitude=41.871311999999996
# longitude=-87.788938
#
# i=618
#
# Online Dates: {datetime.date(2016, 6, 23), datetime.date(2016, 6, 27)}
# Most recent date: 2016-06-27
# names=['Lombard Ave & Garfield St', 'Lombard Ave & Garfield St', 'Lombard Ave & Garfield St', 'Lombard Ave & Garfield St', 'Lombard Ave & Garfield St', 'Lombard Ave & Garfield St']
# unique_names=['Lombard Ave & Garfield St']
# {'Name': ['Lombard Ave & Garfield St'], 'Popularity': [10]}
#                         Name  Popularity
# 0  Lombard Ave & Garfield St          10
# name='Lombard Ave & Garfield St'
# C=575    Oak Park
# 575    Oak Park
# 577    Oak Park
# 577    Oak Park
# Name: City, dtype: object
# city='Oak Park'
# latitude=41.8706692
# longitude=-87.77887559999999
#
# i=619
#
# Online Dates: {datetime.date(2016, 7, 7), datetime.date(2016, 7, 12)}
# Most recent date: 2016-07-12
# names=['Keystone Ave & Fullerton Ave', 'Keystone Ave & Fullerton Ave', 'Keystone Ave & Fullerton Ave', 'Keystone Ave & Fullerton Ave']
# unique_names=['Keystone Ave & Fullerton Ave']
# {'Name': ['Keystone Ave & Fullerton Ave'], 'Popularity': [8]}
#                            Name  Popularity
# 0  Keystone Ave & Fullerton Ave           8
# name='Keystone Ave & Fullerton Ave'
# C=266    Chicago
# 266    Chicago
# 578    Chicago
# 578    Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.924361
# longitude=-87.727752
#
# i=620
#
# Online Dates: {datetime.date(2016, 7, 7), datetime.date(2016, 9, 9)}
# Most recent date: 2016-09-09
# names=['Orleans St & Chestnut St (NEXT Apts)', 'Orleans St & Chestnut St (NEXT Apts)', 'Orleans St & Chestnut St (NEXT Apts)', 'Orleans St & Chestnut St (NEXT Apts)']
# unique_names=['Orleans St & Chestnut St (NEXT Apts)']
# {'Name': ['Orleans St & Chestnut St (NEXT Apts)'], 'Popularity': [8]}
#                                    Name  Popularity
# 0  Orleans St & Chestnut St (NEXT Apts)           8
# name='Orleans St & Chestnut St (NEXT Apts)'
# C=380    Chicago
# 380    Chicago
# 579    Chicago
# 579    Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.898203
# longitude=-87.637536
#
# i=622
#
# Online Dates: {datetime.date(2017, 4, 27)}
# Most recent date: 2017-04-27
# names=['California Ave & Cortez St', 'California Ave & Cortez St', 'California Ave & Cortez St', 'California Ave & Cortez St']
# unique_names=['California Ave & Cortez St']
# {'Name': ['California Ave & Cortez St'], 'Popularity': [4]}
#                          Name  Popularity
# 0  California Ave & Cortez St           4
# name='California Ave & Cortez St'
# C=580    Chicago
# 580    Chicago
# 60     Chicago
# 60     Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.900363
# longitude=-87.696704
#
# i=623
#
# Online Dates: {datetime.date(2017, 6, 13)}
# Most recent date: 2017-06-13
# names=['Michigan Ave & 8th St', 'Michigan Ave & 8th St', 'Michigan Ave & 8th St', 'Michigan Ave & 8th St']
# unique_names=['Michigan Ave & 8th St']
# {'Name': ['Michigan Ave & 8th St'], 'Popularity': [4]}
#                     Name  Popularity
# 0  Michigan Ave & 8th St           4
# name='Michigan Ave & 8th St'
# C=339    Chicago
# 339    Chicago
# 581    Chicago
# 581    Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.872772999999995
# longitude=-87.623981
#
# i=624
#
# Online Dates: {datetime.date(2017, 7, 26)}
# Most recent date: 2017-07-26
# names=['Dearborn St & Van Buren St (*)', 'Dearborn St & Van Buren St (*)']
# unique_names=['Dearborn St & Van Buren St (*)']
# {'Name': ['Dearborn St & Van Buren St (*)'], 'Popularity': [2]}
#                              Name  Popularity
# 0  Dearborn St & Van Buren St (*)           2
# name='Dearborn St & Van Buren St (*)'
# C=582    Chicago
# 582    Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.876268
# longitude=-87.62915500000003
#
# i=625
#
# Online Dates: {datetime.date(2017, 8, 11)}
# Most recent date: 2017-08-11
# names=['Chicago Ave & Dempster St', 'Chicago Ave & Dempster St']
# unique_names=['Chicago Ave & Dempster St']
# {'Name': ['Chicago Ave & Dempster St'], 'Popularity': [2]}
#                         Name  Popularity
# 0  Chicago Ave & Dempster St           2
# name='Chicago Ave & Dempster St'
# C=583    Evanston
# 583    Evanston
# Name: City, dtype: object
# city='Evanston'
# latitude=42.041691
# longitude=-87.680687
#
# i=626
#
# Online Dates: {datetime.date(2017, 12, 21)}
# Most recent date: 2017-12-21
# names=['Delano Ct & Roosevelt Rd', 'Delano Ct & Roosevelt Rd']
# unique_names=['Delano Ct & Roosevelt Rd']
# {'Name': ['Delano Ct & Roosevelt Rd'], 'Popularity': [2]}
#                        Name  Popularity
# 0  Delano Ct & Roosevelt Rd           2
# name='Delano Ct & Roosevelt Rd'
# C=584    Chicago
# 584    Chicago
# Name: City, dtype: object
# city='Chicago'
# latitude=41.867491
# longitude=-87.63219000000002
#
#       ID                            Name   Latitude  Longitude      City  \
# 2      2             Buckingham Fountain  41.874615 -87.622639   Chicago
# 3      3                  Shedd Aquarium  41.867226 -87.615355   Chicago
# 4      4                  Burnham Harbor  41.856268 -87.613348   Chicago
# 5      5          State St & Harrison St  41.874029 -87.627722   Chicago
# 6      6                  DuSable Harbor  41.885042 -87.612795   Chicago
# ..   ...                             ...        ...        ...       ...
# 622  622      California Ave & Cortez St  41.900363 -87.696704   Chicago
# 623  623           Michigan Ave & 8th St  41.872773 -87.623981   Chicago
# 624  624  Dearborn St & Van Buren St (*)  41.876268 -87.629155   Chicago
# 625  625       Chicago Ave & Dempster St  42.041691 -87.680687  Evanston
# 626  626        Delano Ct & Roosevelt Rd  41.867491 -87.632190   Chicago
#
#      DP Capacity Landmark Online Date
# 2             27      541  2015-05-08
# 3             31      544  2015-04-24
# 4             23      545  2015-05-16
# 5             19       30  2013-06-28
# 6             39      548  2015-04-24
# ..           ...      ...         ...
# 622           15     None  2017-04-27
# 623           23     None  2017-06-13
# 624           16     None  2017-07-26
# 625           15     None  2017-08-11
# 626           19     None  2017-12-21
#
# [586 rows x 8 columns]

# %%
new_df
# Out:
#       ID                            Name   Latitude  Longitude      City  \
# 2      2             Buckingham Fountain  41.874615 -87.622639   Chicago
# 3      3                  Shedd Aquarium  41.867226 -87.615355   Chicago
# 4      4                  Burnham Harbor  41.856268 -87.613348   Chicago
# 5      5          State St & Harrison St  41.874029 -87.627722   Chicago
# 6      6                  DuSable Harbor  41.885042 -87.612795   Chicago
# ..   ...                             ...        ...        ...       ...
# 622  622      California Ave & Cortez St  41.900363 -87.696704   Chicago
# 623  623           Michigan Ave & 8th St  41.872773 -87.623981   Chicago
# 624  624  Dearborn St & Van Buren St (*)  41.876268 -87.629155   Chicago
# 625  625       Chicago Ave & Dempster St  42.041691 -87.680687  Evanston
# 626  626        Delano Ct & Roosevelt Rd  41.867491 -87.632190   Chicago
#
#      DP Capacity Landmark Online Date
# 2             27      541  2015-05-08
# 3             31      544  2015-04-24
# 4             23      545  2015-05-16
# 5             19       30  2013-06-28
# 6             39      548  2015-04-24
# ..           ...      ...         ...
# 622           15     None  2017-04-27
# 623           23     None  2017-06-13
# 624           16     None  2017-07-26
# 625           15     None  2017-08-11
# 626           19     None  2017-12-21
#
# [586 rows x 8 columns]

# %%
len(new_df["Online Date"].dropna())
# Out:
# 586

# %%
new_df.to_csv(str(CLEAN_DIR / 'stations.csv'), index=False)

# %%
df
# Out:
#       ID                            Name   Latitude  Longitude  DP Capacity  \
# 0      2        Michigan Ave & Balbo Ave  41.872293 -87.624091           35
# 0      2             Buckingham Fountain  41.876393 -87.620328           27
# 357    2        Michigan Ave & Balbo Ave  41.872638 -87.623979           35
# 52     2             Buckingham Fountain  41.881060 -87.619486           27
# 47     2             Buckingham Fountain  41.872667 -87.623971           35
# ..   ...                             ...        ...        ...          ...
# 581  623           Michigan Ave & 8th St  41.872773 -87.623981           31
# 339  623           Michigan Ave & 8th St  41.872773 -87.623981           23
# 582  624  Dearborn St & Van Buren St (*)  41.876268 -87.629155           16
# 583  625       Chicago Ave & Dempster St  42.041691 -87.680687           15
# 584  626        Delano Ct & Roosevelt Rd  41.867491 -87.632190           19
#
#      Landmark         Online Date      City
# 0       541.0                 NaN       NaN
# 0         NaN     6/10/2013 10:43   Chicago
# 357       NaN            5/8/2015       NaN
# 52        NaN  6/10/2013 10:43:46   Chicago
# 47        NaN            5/8/2015       NaN
# ..        ...                 ...       ...
# 581       NaN     6/13/2017 15:23   Chicago
# 339       NaN  6/13/2017 15:23:53   Chicago
# 582       NaN     7/26/2017 21:25   Chicago
# 583       NaN     8/11/2017 16:53  Evanston
# 584       NaN    12/21/2017 22:06   Chicago
#
# [3938 rows x 8 columns]

# %% [markdown]
# ## Other Stations

# %% [markdown]
# Other station IDs were found in the CSV files describing all the bike trips.

# %%
from_ids = unique_values("From Station ID")
to_ids = unique_values("To Station ID")

# %%
stations = pd.read_csv(CLEAN_DIR / 'stations.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_109570/2550475111.py in <module>
# ----> 1 stations = pd.read_csv(CLEAN_DIR / 'stations.csv')
#
# NameError: name 'pd' is not defined
